# %% [markdown]
# <a href="https://colab.research.google.com/github/fdsig/iaqa/blob/main/Copy_of_Copy_of_AVA_Train_Final.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import auth
auth.authenticate_user()

# %%
# %%capture 
# get dependacies 
# !pip -q install vit_pytorch linformer
# !rm -rf vit-pytorch/ && rm -rf image_utils
# to obtian AVA Dataset withough needing to dowload or mount your own drive
# !git clone https://github.com/fdsig/image_utils
# moves image getter (ava data) into working directory
# !mv image_utils/image_getter.py ./image_getter.py
# !pip install timm
# !pip uninstall albumentations -y
# !pip install albumentations
# !pip uninstall opencv-python-headless==4.5.5.62 -y
# !pip install opencv-python-headless==4.5.2.52  
# !pip install wandb -qqq
# !pip install git+https://github.com/rwightman/pytorch-image-models.git

# %%
# wandb integration loging in at start
import wandb
wandb.login(force=True,relogin=True)

# %%
from google.colab import drive
def mount():
    #mount drive for saving results 
    #need to go through the usual authorization dance
    drive.flush_and_unmount()
    drive.mount('/content/drive', force_remount=True) 
mount()

# %%
# !ls -a drive/MyDrive/ava_batches

# %%
from __future__ import print_function
import json
import cv2
import glob
from itertools import chain
import os
import pandas as pd
import random
# file handling
import zipfile
import shutil
from pathlib import Path

import albumentations as A
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from linformer import Linformer
from PIL import Image
from sklearn.model_selection import train_test_split
from torch.optim.lr_scheduler import StepLR
from torch.utils.data import DataLoader, Dataset
from torchvision import datasets, transforms
from tqdm import tqdm
from vit_pytorch.efficient import ViT
from sklearn.utils import class_weight
import time
import copy
from sklearn.preprocessing import LabelEncoder

#
import timm
from timm.scheduler import create_scheduler
from timm.optim import create_optimizer

from albumentations import pytorch
from pathlib import Path
import torchvision
import gc
from pathlib import Path

from sklearn import metrics
from vit_pytorch.cvt import CvT

# %%
# equivalent to:
#!cp -r drive/MyDrive/ava_batches_demo batches
origionals = Path('drive/MyDrive/ava_batches/')
target = Path('batches/')
if not target.exists():
  target.mkdir()
fids = [fid for fid in origionals.iterdir()]
for fid in tqdm(fids,colour=("#FF69B4")):
  shutil.copy(fid.as_posix(),target/fid.name)

# %%
paths = [i for i in os.scandir('batches')]
for zip_f in tqdm(paths, colour=("#FF69B4")):
                zip_ref = zipfile.ZipFile(zip_f, "r")
                zip_ref.extractall("./Images/")
                zip_ref.close()
                os.remove(zip_f)

      

root = Path("Images")
images = [file for folder in root.iterdir() for file in folder.iterdir()]
print(images[0].name)
for img in images:
  img.rename(root/img.name)

for i in root.iterdir():
  if i.is_dir():
    i.rmdir()

# %%
len(list(root.iterdir()))
# Out:
# 255508

# %%
avail_pretrained_models = timm.list_models(pretrained=True)
[net for net in avail_pretrained_models if 'mobile' in net and 'tf' not in net and 'rw' not in net]
# Out:
# ['mobilenetv2_050',
#  'mobilenetv2_100',
#  'mobilenetv2_110d',
#  'mobilenetv2_120d',
#  'mobilenetv2_140',
#  'mobilenetv3_large_100',
#  'mobilenetv3_large_100_miil',
#  'mobilenetv3_large_100_miil_in21k',
#  'mobilenetv3_small_050',
#  'mobilenetv3_small_075',
#  'mobilenetv3_small_100',
#  'mobilevit_s',
#  'mobilevit_xs',
#  'mobilevit_xxs']

# %%
from matplotlib import rcParams
def scalar_resize(fid,scalar=None):
    img = cv2.imread(fid.path, cv2.IMREAD_UNCHANGED)
    shape = np.array(img.shape)
    scalar = scalar/shape[shape.argmax()]
    shape = np.ceil(shape*scalar).astype(int)
    dim = (shape[1], shape[0])
    # resize image
    return cv2.resize(img, dim, interpolation = cv2.INTER_AREA)

def get_df():
    df = pd.read_csv('/content/image_utils/ava_meta_with_int_id_230721.csv')
    display(df)
    plt.hist(df['MLS'].values.ravel(), bins=10)
    plt.show()
    return df

def meta_process(df=None):
    y_gt = df['mos_float'].values
    ids = df['ID'].values
    print(len(ids))
    y_gt_std, y_gt_mean = np.std(y_gt, axis = 0), np.mean(y_gt, axis = 0)
    exclude_below = y_gt_mean-y_gt_std*4
    exclude_above = y_gt_mean+y_gt_std*4
    ids = ids[np.argwhere(y_gt>=exclude_below)].ravel()
    y_gt = y_gt[np.argwhere(y_gt>=exclude_below)].ravel()
    print(len(y_gt))
    ids = ids[np.argwhere(y_gt<=exclude_above)].ravel()
    y_gt = y_gt[np.argwhere(y_gt<=exclude_above)].ravel()
    print(len(ids),len(y_gt))
    ids_low = ids[np.argwhere(y_gt<5)].ravel().astype(int)
    ids_high = ids[np.argwhere(y_gt>5)].ravel().astype(int)
    to_include = np.concatenate((ids_low,ids_high), axis=0)
    len(to_include)
    return df[df['ID'].isin(to_include)]


def one_hot(df):
    one_hot = pd.get_dummies(df['MLS'])
    one_hot = pd.merge(df['ID'],one_hot, right_on=df.index, left_index=True)
    one_hot = one_hot[one_hot.columns[1:]]
    y_df = pd.merge(one_hot,df[['threshold', 'ID','MOS','MLS','set']], right_on=one_hot.index, left_index=True)
    return y_df[y_df.columns[2:]]



def sort_show():
    ava = [ i.path for i in os.scandir('Images/')]
    ava.sort()
    read = lambda fid: cv2.cvtColor(cv2.imread(fid), 
                                    cv2.COLOR_BGR2RGB)
    img = read(ava[0])
    print(img.shape)
    fig, ax = plt.subplots(1,1, figsize=(5,5))
    ax.imshow(img)


def get_labels(df):
    y_df = one_hot(df)
    labels = (
            fid.name.split('.')[0] 
            for path in os.scandir('Images/') 
            for fid in os.scandir(path.path))
    y_g = y_df.to_dict('index')
    return {str(y_g[pair_key]['ID_y']):y_g[pair_key] for pair_key in y_g}

def make_class_dir(df,y_g_dict):
    '''creates text train val with class subdirs
    
    ⌊_train
    |     ⌊_class 0
    |     ⌊_class 1
    ⌊_test
    |     ⌊_class 0
    |     ⌊_class 1
    ⌊_val_
          ⌊_class 0
          ⌊_class 1'''
    
    os.makedirs('data/', exist_ok=True)
    train_dir = 'data/train/'
    test_dir = 'data/test/'
    #!rm -rf data/train/ && rm -rf data/test/
    os.makedirs(train_dir, exist_ok=True)
    os.makedirs(test_dir,exist_ok=True)
    not_loaded_train, not_loaded = [ ], [ ]
    test_df = df[df['set']=='test']
    files_ = [i.name for i in os.scandir('Images/')]
    test_set = test_df['image_name'].values
    for im_id in tqdm(test_set, colour=('#FF69B4')):
        key = im_id.strip('.jpg')
        y_g_dict[key]['fid']='data/test/'+im_id
        try:
        
            os.symlink('Images/'+im_id,'data/test/'+im_id)
        except:
            not_loaded.append(im_id)
    train_df = df[df['set'].isin(['training','validation'])]
    train_set = train_df['image_name'].values
    for im_id in tqdm(train_set, colour=('#FF69B4')):
        key = im_id.strip('.jpg')
        y_g_dict[key]['fid']='data/train/'+im_id
        try:
        
            os.symlink('Images/'+im_id,'data/train/'+im_id)
        except:
            not_loaded_train.append(im_id)
            
    return y_g_dict
    

def class_wts(df):
    '''computes class weights for training samplere'''
    y_gt = df.values.ravel()
    y_gt_ = np.array(y_gt)
    y = np.bincount(y_gt_)
    x = np.unique(y_gt_)
    print(len(y),len(x))
    plt.bar(x,y)
    plt.show()
    class_weights=class_weight.compute_class_weight('balanced',classes=x,y=y_gt_)
    class_weights=torch.tensor(class_weights,dtype=torch.float)
    print(class_weights) 
    return class_weights, y

def image_plot(image_dict, eval_list=None, super_title = None, n_images=None, evaluate=None):
    '''plots random images'''
    rcParams['axes.titlepad'] = 10
    if not evaluate:
        random_keys = np.random.choice(
        list(image_dict.keys()), n_images, replace=False
        )
    if evaluate:
        eval_list = [
                     name.split('.')[0] for name in eval_list
                     ]
        random_keys = np.random.choice(
        eval_list, n_images, replace=False
        )
        

    cvt = lambda img: cv2.cvtColor(cv2.imread(img, cv2.IMREAD_UNCHANGED), cv2.COLOR_BGR2RGB)
    if random_keys.__class__==np.ndarray:
        fig, axes = plt.subplots(1,len(random_keys), figsize=(15,10))
        for idx, ax in enumerate(axes.ravel()):
            print(random_keys)
            img = cvt(os.readlink(image_dict[random_keys[idx]]['fid']))
            ax.axis("off")
            ax.set_yticks([])
            ax.set_xticks([])
            meta = image_dict[random_keys[idx]]
            title = f"ID:{random_keys[idx]} MOS:{meta['MOS']:.2f}"
            
            if meta['threshold'] ==1:
                cls_ = 0
            else:
                cls_ = 1
            title += f"\nBinary Class: {cls_}"
            ax.set_title(title, size=20)
            ax.imshow(img)
        fig.suptitle(super_title, fontsize=24)
        fig.savefig(super_title+'.png')
        plt.show()
    else:
    
        fig, ax = plt.subplots(1,1, figsize=(10,10))
        ax.axis("off")
        print(random_keys)
        img = cvt(os.readlink(image_dict[random_keys]['fid'])) 
        ax.set_yticks([])
        ax.set_xticks([])
        meta = image_dict[random_keys]
        title = f"ID:{random_keys} MOS:{meta['MOS']:.2f}"
        if meta['threshold'] ==1:
            cls_ = 0
        else:
            cls_ = 1
        title += f"\nBinary Class: {cls_}"
        title += f"\nBinary Class: {meta['threshold']}"
        ax.set_title(title, size=20)
        ax.imshow(img)
        fig.suptitle(super_title, fontsize=24)
        fig.savefig(super_title+'.png')
        plt.show()

def get_all():
    '''meta fucntion for calling other fuctions'''
    df = get_df()
    df = meta_process(df=df)
    class_weights, class_counts = class_wts(df['threshold'])
    y_g_dict = get_labels(df)
    make_class_dir(df,y_g_dict)
    y_g_neg = {key:y_g_dict[key] for key in y_g_dict if y_g_dict[key]['threshold']==0}
    y_g_pos = {key:y_g_dict[key] for key in y_g_dict if y_g_dict[key]['threshold']==1}
    sets = ['test', 'training', 'validation']
    splits ={
        set_: {
            im_key:y_g_dict[im_key] for im_key in y_g_dict 
            if y_g_dict[im_key]['set']==set_
            } for set_ in sets
            }
    print(f"train set n = {len(splits['training'])} \ntest_list n = {len(splits['test'])}\nvalidation_list n = {len(splits['validation'])}")
    return df, y_g_dict, splits, y_g_neg, y_g_pos

def data_transforms(size=None):
    '''defines data transform and returns a dict with test,train,val transforms'''
    mask1 = np.full(30 * 140, False) 
    a_train_transform = A.Compose(
        [
         A.augmentations.transforms.GridDistortion(
                num_steps=5, 
                distort_limit=0.6, 
                interpolation=1, 
                border_mode=4, 
                value=4, 
                mask_value=2, 
                always_apply=False, 
                p=0.1),
            A.augmentations.geometric.resize.LongestMaxSize(
                max_size=size
                ),
            A.augmentations.transforms.PadIfNeeded(size,size),
            A.augmentations.transforms.Normalize(
                mean=(0.485, 0.456, 0.406), 
                std=(0.229, 0.224, 0.225), 
                max_pixel_value=255.0, p=1.0),
            #A.augmentations.transforms.MedianBlur(blur_limit=7, always_apply=False, p=0.5)
            A.augmentations.transforms.CoarseDropout (max_holes=10, 
                                                      max_height=72, 
                                                      max_width=72, 
                                                    min_holes=3, 
                                                    min_height=36, 
                                                    min_width=36, 
                                                    fill_value=(random.uniform(0, 1),
                                                                random.uniform(0, 1), 
                                                                random.uniform(0, 1)) , 
                                                      mask_fill_value=(0.5,0.2,0.4), 
                                                      always_apply=False, p=0.1),
            A.augmentations.transforms.ColorJitter(brightness=0.05, 
                                                   contrast=0.05, 
                                                   saturation=0.05, 
                                                   hue=0.05, 
                                                   always_apply=False,
                                                   p=0.1),
            A.augmentations.transforms.Cutout(
                num_holes=8, 
                max_h_size=36, 
                max_w_size=36, 
                fill_value=(
                    random.uniform(0, 1),
                    random.uniform(0, 1), 
                    random.uniform(0, 1)
                    ),
                always_apply=False, 
                p=0.1
                ),
            A.augmentations.transforms.GaussianBlur(
                blur_limit=(3, 5), 
                sigma_limit=0, 
                always_apply=False, 
                p=0.1
                ),
            A.augmentations.transforms.GaussNoise(
                var_limit=(0.1, 0.1), 
                mean=0.1, 
                per_channel=True, 
                always_apply=False, 
                p=0.1
                ),
            A.augmentations.transforms.HueSaturationValue(
                hue_shift_limit=0.1, 
                sat_shift_limit=0.1, 
                val_shift_limit=0.1, 
                always_apply=False, 
                p=0.01
                ),
            A.augmentations.transforms.MotionBlur(
                blur_limit=3,p=0.2
                ),
            A.augmentations.geometric.rotate.SafeRotate(limit=30, 
                                                        interpolation=1, 
                                                        border_mode=4, 
                                                        value=None, 
                                                        mask_value=None, 
                                                        always_apply=False, 
                                                        p=0.1
                                                        ),
        
            A.pytorch.transforms.ToTensorV2(
                transpose_mask=False, p=1.0
                )
            ]
            )

    a_test_transform = A.Compose([
            A.augmentations.geometric.resize.LongestMaxSize(max_size=224),
            A.augmentations.transforms.PadIfNeeded(224,224),
            A.augmentations.transforms.Normalize(mean=(0.485, 0.456, 0.406), std=(0.229, 0.224, 0.225), 
                                                max_pixel_value=255.0, p=1.0),
                            A.pytorch.transforms.ToTensorV2(transpose_mask=False, p=1.0) ]
                            )



    a_valid_transform = A.Compose([
            A.augmentations.geometric.resize.LongestMaxSize(max_size=224),
            A.augmentations.transforms.PadIfNeeded(224,224),
            A.augmentations.transforms.Normalize(mean=(0.485, 0.456, 0.406), std=(0.229, 0.224, 0.225), 
                                                max_pixel_value=255.0, p=1.0),
                            A.pytorch.transforms.ToTensorV2(transpose_mask=False, p=1.0) ]
                            )
    return {'test':a_test_transform, 'training':a_train_transform , 'validation':a_valid_transform}




def plot_transform(data_dict):
    '''plots data transforms'''
    idx = 11
    read = lambda fid: cv2.cvtColor(cv2.imread(os.readlink(fid)), cv2.COLOR_BGR2RGB).astype(np.uint8)


    cvt = lambda img: cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    img_fid = y_g_dict[list(y_g_dict.keys())[idx]]['fid']
    img = read(img_fid).astype(np.uint8)
    img_array = read(y_g_dict[list(y_g_dict.keys())[idx]]['fid'])

    #permute(1,2,0) permutes value of transfrom 'image' item from tesor to RGB 3 * 224 * 224
    refleciton_pad_array = reflect_transforms['training'](image=img)['image'].permute(1,2,0)

    print(img.shape)

    #zero_pad_array = train_transforms(Image.fromarray(img_array)).permute(1,2,0)
    fig, axs = plt.subplots(2,3, figsize=(15,15))
    no_transform_fid = read(img_fid)

    transforms_dict = {'no_tranform': no_transform_fid,
                'from_array': img_array,
                'reflection_from_Pad_array': refleciton_pad_array}
    for idx_ in range(3):
        img_fid = y_g_dict[list(y_g_dict.keys())[idx]]['fid']
        img = read(img_fid).astype(np.uint8)
        transforms_dict['reflect'+str(idx_)]=reflect_transforms['training'](image=img)['image'].permute(1,2,0)



    for item in enumerate(transforms_dict):
        idx, key = item
        if idx<3:
            row=0
        else:
            row=1
            idx-=3
        axs[row,idx].imshow(transforms_dict[key])
        axs[row,idx].set_title(key)
        axs[row,idx].set_ylabel(transforms_dict[key].shape[0])
        axs[row,idx].set_xlabel(transforms_dict[key].shape[1])
        if str(type(transforms_dict[key]))!="<class 'numpy.ndarray'>":
            print(type(transforms_dict[key]) )
            cv2.imwrite(key+'.png',transforms_dict[key].numpy().astype(np.uint8))
    plt.savefig('transfroms.png', dpi=300)

def data_samplers(data, data_class, batch_size=None):
    '''retrurns data loaders called during training'''
    test_ids = [idx for idx in data['training']][:20]
    # a small subset for debugging if needed <^_^> 
    data_tester = {key:data['training'][key] for key in test_ids}
    #change back

    train_data_loader =  ava_data_reflect(
        data['training'], transform=reflect_transforms['training']
        )
    val_data_loader =  ava_data_reflect(
        data['validation'], transform=reflect_transforms['validation']
        )
    test_data_loader =  ava_data_reflect(
        data['test'], transform=reflect_transforms['test']
        )
    data_load_dict = {
        'training':train_data_loader,
        'validation':val_data_loader, 
        'test': test_data_loader
        }
    #Let there be 9 samples and 1 sample in class 0 and 1 respectively
    labels = [data['training'][idx]['threshold'] for idx in data['training']]
    class_counts = np.bincount(labels)
    num_samples = sum(class_counts)
    #corresponding labels of samples
    class_weights = [num_samples/class_counts[i] for i in range(len(class_counts))]
    weights = [class_weights[labels[i]] for i in range(int(num_samples))]
    sampler = torch.utils.data.WeightedRandomSampler(
        torch.DoubleTensor(weights), int(num_samples)
        )
    print(len(weights))
    print(class_weights)
    sampler = torch.utils.data.WeightedRandomSampler(
        torch.DoubleTensor(weights), int(len(data['training'].keys()))
        )
    # with data sampler (note ->> must be same len[-,...,-] as train set!!)
    train_loader = DataLoader(
        dataset = train_data_loader, 
        sampler=sampler, 
        batch_size=batch_size,
        shuffle=False
        )

    val_loader = DataLoader(
        dataset = val_data_loader, 
        batch_size=batch_size, 
        shuffle=False
        )
    test_loader = DataLoader(
        dataset = test_data_loader,
         batch_size=batch_size, shuffle=True)
    return {'training':train_loader,'validation':val_loader, 'test': test_loader}

def seed_everything(seed):
    random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    torch.backends.cudnn.deterministic = True


def train_model(model, criterion, 
                optimizer, 
                scheduler, 
                num_epochs=None, 
                model_name = None, 
                did = None,
                data = None):
    '''Training and validation loops- 1 loop == one epoch
    has a saving fuciton saving model on best epoch
    records total train time'''
    results = { }
    # pathlib path object --> most pythonic option. 
    did = Path(did)
    did = did/model_name
    os.makedirs(did,exist_ok=True)
    print(f'currently trianing {model_name}')
    print(f'{model_name} will be saved at {did/model_name}')
    since = time.time()
    # copy state dict for best model saving (training could make them worse)
    best_model_wts = copy.deepcopy(model.state_dict())
    best_acc = 0.0

    for epoch in range(num_epochs):
        print('Epoch {}/{}'.format(epoch, num_epochs - 1))
        print('-' * 10)

        # Each epoch has a training and validation phase
        for phase in ['training', 'validation']:
            dataset_size = len(data[phase])
            print(dataset_size)
            if phase == 'training':
                model.train()   # Set model to training mode
            else:
                model.eval()   # Set model to evaluate mode

            running_loss = 0.0
            running_corrects = 0
            print(phase)
            # Iterate over data.
            for inputs, labels,fid in tqdm(data_load_dict[phase]):
                #wandb.log({"examples" : [wandb.Image(im) for im in inputs]})
                inputs = inputs.to(device)
                labels = labels.to(device)

                # zero the parameter gradients
                optimizer.zero_grad()

                # forward
                # track history if only in train
                with torch.set_grad_enabled(phase == 'training'):
                    outputs = model(inputs)
                    _, preds = torch.max(outputs, 1)
                    loss = criterion(outputs, labels)

                    # backward + optimize only if in training phase
                    if phase == 'training':
                        loss.backward()
                        optimizer.step()

                # statistics
                running_loss += loss.item() * inputs.size(0)
                running_corrects += torch.sum(preds == labels.data)
            if phase == 'training':
                scheduler[0].step(scheduler[1])

            ballance = np.array([])
            epoch_loss = running_loss / dataset_size
            epoch_acc = running_corrects.double() / dataset_size
            class_preds = outputs.argmax(dim=1) 
            batch_acc = metrics.balanced_accuracy_score(labels.cpu(), 
                                                         class_preds.cpu())
            ballance = np.append(ballance, batch_acc)

            print('{} Loss: {:.4f} Acc: {:.4f}'.format(
                phase, epoch_loss, epoch_acc))
            key = 'epoch_'+str(epoch+1)+'_'+phase
            results[key]= {
                phase+' loss' : epoch_loss, 
                phase+' acc': float(epoch_acc.cpu()),
                phase+ ' ballance_acc':ballance.mean()
                }
            wandb.log({
                phase+' loss' : epoch_loss, 
                phase+' acc': float(epoch_acc.cpu()),
                phase+ ' ballance_acc':ballance.mean()
                })
            # w mode to overwirte existing json - reading and re writing 
            # in append modes can cause jsaon formatting issues
            # files are json for ease of loading to python dict in evaluation
            still_to_train = num_epochs - epoch
            save_fid = did/(model_name+f'_epoch_{10-still_to_train}.json')
            with open(save_fid, 'w') as handle:
                json.dump(results, handle)
            print(results)

            # deep copy the model
            if phase == 'validation' and epoch_acc > best_acc:
                best_acc = epoch_acc 
                best_model_wts = copy.deepcopy(model.state_dict())
                torch.save({'epoch':epoch, 
                            'model_state_dict':model.state_dict(),
                            'optimizer_state_dict':optimizer.state_dict()
                            }, did/model_name)
                wandb.log({'best_epoch':epoch})
                print(f'Saving {model_name} in {did.name}')
                #model save

    time_elapsed = time.time() - since
    t_mins, t_seconds = time_elapsed // 60, time_elapsed % 60
    train_overall = {
        'mins':t_mins, 
        'seconds':t_seconds, 
        'best_acc': best_acc.cpu().tolist()
        }
    wandb.log(train_overall)
    print(f'training time = {train_overall}')
    with open(did/('train_overall'+'.json'), 'w') as handle:
        json.dump(train_overall, handle)


def loader(models):
    '''genrator for models when loooping through all models'''
    for mod in models:
        print(mod)
        if 'ResNet' in mod:
            loaded = torch.load(models[mod])
            res_n = models[mod].name.split('_')[-1]
            if '18' == res_n:
                model = torchvision.models.resnet18(pretrained=True)
            elif '50' == res_n:
                model = torchvision.models.resnet50(pretrained=True)
            else:
                model = torchvision.models.resnet152(pretrained=True)
            feature_in = model.fc.in_features
            model.fc = nn.Linear(feature_in, 2)
            model.load_state_dict(loaded['model_state_dict'])
        elif'ConViT' in mod:
            print(models[mod].parent.name)
            loaded = torch.load(models[mod])
            print(loaded.keys())
            model = timm.create_model(models[mod].name.strip(models[mod].suffix)
            , pretrained=True)
            model.head = nn.Linear(model.head.in_features,2,bias=True)
            if 'pth' in models[mod].name:
                model.load_state_dict(loaded['model'])
            else:
                model.load_state_dict(loaded['model'])
        elif 'CvT' in mod:
            loaded = torch.load(models[mod])
            model = CvT(
                        num_classes = 2,
                        s1_emb_dim = 64,      
                        s1_emb_kernel = 7,     
                        s1_emb_stride = 4,      
                        s1_proj_kernel = 3,     
                        s1_kv_proj_stride = 2,  
                        s1_heads = 1,         
                        s1_depth = 1,         
                        s1_mlp_mult = 4,        
                        s2_emb_dim = 192,      
                        s2_emb_kernel = 3,
                        s2_emb_stride = 2,
                        s2_proj_kernel = 3,
                        s2_kv_proj_stride = 2,
                        s2_heads = 3,
                        s2_depth = 2,
                        s2_mlp_mult = 4,
                        s3_emb_dim = 384,     
                        s3_emb_kernel = 3,
                        s3_emb_stride = 2,
                        s3_proj_kernel = 3,
                        s3_kv_proj_stride = 2,
                        s3_heads = 4,
                        s3_depth = 10,
                        s3_mlp_mult = 4,
                        dropout = 0.
                    )
            model.load_state_dict
            model.load_state_dict(loaded['model_state_dict'])
        elif 'mobilenet' in mod:
            print(mod)
            model = timm.create_model(mod , pretrained=True)
            model.classifier.out_featrues=2
        elif 'mobilevit' in mod:
            print(mod)
            model = timm.create_model(mod , pretrained=True)
            model.head.fc.out_features=2
        else:
            model = timm.create_model(mod , pretrained=True)
            model.head.fc.out_features=2
        
        yield model,models[mod]['epochs'],mod
            
def deep_eval(model):
    '''validatioan loop ruturns metrics dict for passed model'''
    criterion = nn.CrossEntropyLoss()
    model.to(device)
    results_dict = { }
    with torch.no_grad():
        model.eval()
        for data, label, fid in tqdm(data_load_dict['test']):
            data = data.to(device)
            label = label.to(device)
            output = model(data)            
            sm = torch.nn.Softmax(dim=1)
            probabilities = sm(output)
            for dir_,prob,lab in zip(fid,probabilities,label):
                results_dict[dir_.split('/')[-1]]={ 
                    'class_probs':prob.cpu().tolist(), 
                    'pred_class': int(prob.argmax(dim=0).cpu()), 
                    'g_t_class': int(lab.cpu())}
            val_loss = criterion(output, label)
            acc = (output.argmax(dim=1) == label).float().mean()
            results_dict['test_accuracy']={'test_acc':float(acc.cpu())}
    return results_dict

# %%
class ava_data_reflect(Dataset):
    '''data class wich is used by data loader retruns transformed image '''
    def __init__(self, im_dict, state = None, transform=None):
        self.im_dict = im_dict
        self.transform = transform
        self.files  = list(im_dict.keys())
        self.state = state

    def __len__(self):
        self.filelength = len(self.im_dict.keys())
        return self.filelength

    def __getitem__(self, idx):
        #img_path = self.im_dict[self.files[idx]]['fid']
        # reads symbolic links from test val train dirs returns rgb array
        read = lambda fid: cv2.cvtColor(cv2.imread(os.readlink(fid)), cv2.COLOR_BGR2RGB).astype(np.uint8)
        img = self.im_dict[self.files[idx]]['fid']
        img = read(img)
        # stacks grayscale images 
        if len(img.shape) !=3:
            img = np.stack([np.copy(img) for i in range(3)], axis=2)
             
        #img = self.a_transform(image=img)['image']
        # converst to pillow image from arry
        # this is faster as open cv reads image 
        # faster than pillow
        # pillow also returns file read errors
        # for some image in ava dataset
        # cv2 does not. 
        #img = Image.fromarray(img.astype('uint8'), 'RGB')
        
        img_transformed = self.transform(image=img)['image']
        # gets one hot (binary) thresholded groud truth

        label = int(self.im_dict[self.files[idx]]['threshold'])

        # uncomment to check that lable and data loading correctly (debug)
        #print(label, self.im_dict[self.files[idx]])

        

        return img_transformed, label, self.im_dict[self.files[idx]]['fid']

# %% [markdown]
# set own derive to false if you have not downloaded/uploaded AVA Benchmarking dataset to your ownd google drive and are mounting.
#
# If set to false will retrive from fdesigleys google drive (shared files).

# %%
# !ls drive/MyDrive/ava_batches/
# Out:
# Batch_0.zip   Batch_18.zip  Batch_26.zip  Batch_34.zip	Batch_42.zip
# Batch_10.zip  Batch_19.zip  Batch_27.zip  Batch_35.zip	Batch_43.zip
# Batch_11.zip  Batch_1.zip   Batch_28.zip  Batch_36.zip	Batch_4.zip
# Batch_12.zip  Batch_20.zip  Batch_29.zip  Batch_37.zip	Batch_5.zip
# Batch_13.zip  Batch_21.zip  Batch_2.zip   Batch_38.zip	Batch_6.zip
# Batch_14.zip  Batch_22.zip  Batch_30.zip  Batch_39.zip	Batch_7.zip
# Batch_15.zip  Batch_23.zip  Batch_31.zip  Batch_3.zip	Batch_8.zip
# Batch_16.zip  Batch_24.zip  Batch_32.zip  Batch_40.zip	Batch_9.zip
# Batch_17.zip  Batch_25.zip  Batch_33.zip  Batch_41.zip

# %%
df,y_g_dict, data, neg, pos = get_all()
# Out:
#         Unnamed: 0  Unnamed: 0.1  1  2   3   4   5   6   7   8  ...  \
# 0                0             0  0  0   0   5  32  50  23  10  ...
# 1                1             1  0  3   2   3  13  40  35  21  ...
# 2                2             2  0  2   3   9  35  50  20   5  ...
# 3                3             3  0  1   7  26  56  23   6   1  ...
# 4                4             4  0  1   4   5  33  50  17   9  ...
# ...            ...           ... .. ..  ..  ..  ..  ..  ..  ..  ...
# 255497      255497        255497  1  7  17  40  84  56  31  13  ...
# 255498      255498        255498  1  0   8  25  50  65  55  26  ...
# 255499      255499        255499  0  0   8  11  26  47  48  56  ...
# 255500      255500        255500  0  2  19  30  75  60  30  25  ...
# 255501      255501        255501  1  3  10  39  51  61  39  29  ...
#
#         challenge_id       MOS  image_name  MLS       set  width height  \
# 0               1396  6.112903  953417.jpg    6  training  781.0  699.0
# 1               1396  6.593750  953777.jpg    6  training  550.0  800.0
# 2               1396  5.796875  953756.jpg    6  training  800.0  594.0
# 3               1396  5.040984  954195.jpg    5  training  587.0  674.0
# 4               1396  5.943548  953903.jpg    6  training  800.0  533.0
# ...              ...       ...         ...  ...       ...    ...    ...
# 255497           181  5.339844   56938.jpg    5  training  640.0  456.0
# 255498           181  6.235294   57304.jpg    6  training  583.0  640.0
# 255499           181  7.072581   56711.jpg    8  training  640.0  485.0
# 255500           181  5.608871   57303.jpg    5  training  640.0  423.0
# 255501           181  5.853061   57221.jpg    6  training  640.0  484.0
#
#             ID threshold  mos_float
# 0       953417         1   6.112903
# 1       953777         1   6.593750
# 2       953756         1   5.796875
# 3       954195         1   5.040984
# 4       953903         1   5.943548
# ...        ...       ...        ...
# 255497   56938         1   5.339844
# 255498   57304         1   6.235294
# 255499   56711         1   7.072581
# 255500   57303         1   5.608871
# 255501   57221         1   5.853061
#
# [255502 rows x 24 columns]
# 255502
# 255411
# 255403 255403
# 2 2
# tensor([1.7220, 0.7046])
# 100%|██████████| 19899/19899 [00:00<00:00, 59098.30it/s]
# 100%|██████████| 235121/235121 [00:04<00:00, 54803.50it/s]
# train set n = 223363
# test_list n = 19899
# validation_list n = 11758

# %%
# shows one n.random negative image (can be set to more)
image_plot(neg, super_title='Negative Images (MOS below 5)')
# Out:
# 204706

# %%
# shows one .ranndom positive (can be set to more)
image_plot(pos, super_title='Positive Images (MOS above 5)')
# Out:
# 46612

# %%
reflect_transforms = data_transforms(size=224)
plot_transform(y_g_dict)
# Out:
# /usr/local/lib/python3.7/dist-packages/albumentations/augmentations/transforms.py:691: FutureWarning: This class has been deprecated. Please use CoarseDropout
#   FutureWarning,
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# (533, 800, 3)
# <class 'torch.Tensor'>
# <class 'torch.Tensor'>
# <class 'torch.Tensor'>
# <class 'torch.Tensor'>

# %%
df
# Out:
#         Unnamed: 0  Unnamed: 0.1  1  2   3   4   5   6   7   8  ...  \
# 0                0             0  0  0   0   5  32  50  23  10  ...
# 1                1             1  0  3   2   3  13  40  35  21  ...
# 2                2             2  0  2   3   9  35  50  20   5  ...
# 3                3             3  0  1   7  26  56  23   6   1  ...
# 4                4             4  0  1   4   5  33  50  17   9  ...
# ...            ...           ... .. ..  ..  ..  ..  ..  ..  ..  ...
# 255497      255497        255497  1  7  17  40  84  56  31  13  ...
# 255498      255498        255498  1  0   8  25  50  65  55  26  ...
# 255499      255499        255499  0  0   8  11  26  47  48  56  ...
# 255500      255500        255500  0  2  19  30  75  60  30  25  ...
# 255501      255501        255501  1  3  10  39  51  61  39  29  ...
#
#         challenge_id       MOS  image_name  MLS       set  width height  \
# 0               1396  6.112903  953417.jpg    6  training  781.0  699.0
# 1               1396  6.593750  953777.jpg    6  training  550.0  800.0
# 2               1396  5.796875  953756.jpg    6  training  800.0  594.0
# 3               1396  5.040984  954195.jpg    5  training  587.0  674.0
# 4               1396  5.943548  953903.jpg    6  training  800.0  533.0
# ...              ...       ...         ...  ...       ...    ...    ...
# 255497           181  5.339844   56938.jpg    5  training  640.0  456.0
# 255498           181  6.235294   57304.jpg    6  training  583.0  640.0
# 255499           181  7.072581   56711.jpg    8  training  640.0  485.0
# 255500           181  5.608871   57303.jpg    5  training  640.0  423.0
# 255501           181  5.853061   57221.jpg    6  training  640.0  484.0
#
#             ID threshold  mos_float
# 0       953417         1   6.112903
# 1       953777         1   6.593750
# 2       953756         1   5.796875
# 3       954195         1   5.040984
# 4       953903         1   5.943548
# ...        ...       ...        ...
# 255497   56938         1   5.339844
# 255498   57304         1   6.235294
# 255499   56711         1   7.072581
# 255500   57303         1   5.608871
# 255501   57221         1   5.853061
#
# [255020 rows x 24 columns]

# %%
def get_meta(parent=None):
    ''' creates data frame from available data'''
    # for creating numeric lables form sklearn

    # function to read and permute chanels to RGB from BGR 
    read = lambda img: cv2.cvtColor(cv2.imread(img), cv2.COLOR_BGR2RGB)
    meta = { }
    # flatten to list of all image files
    fids = [fid for fid in parent.iterdir()]
    for fid in tqdm(fids):
        img = read(fid.as_posix())
        meta[fid.name] = [#get mean red
                          img[...,0].mean(),
                          #get mean green
                          img[...,1].mean(),
                          #get mean blue
                          img[...,2].mean(),
                          #get img chanels
                          img.shape[0],
                          #get img width
                          img.shape[1],
                          #get img height
                          img.shape[2],
                          #get bool color
                          img.shape[0]*img.shape[1],
                          #compute resolution w*h
                          img.shape[2]==3,
                          # system specific image path
                          fid,
                          # image name
                          fid.name,
                          # data file type
                          fid.suffix
                       ]
    # creates column headings for data frame
    columns=['red',
             'green',
             'blue',
             'width',
             'height',
             'chanels',
             'resolution',
             'color',
             'file',
             'image_name',
             'type']
    df = pd.DataFrame.from_dict(meta,orient='index',columns=columns)
    # adds codding numeric encoding from unique class labels
    return df.sort_values(by='image_name')

# %%
meta_data('Images/144050.jpg')

# %%
device = 'cuda'
data_load_dict = data_samplers(data,ava_data_reflect,batch_size=128)
torch.clear_autocast_cache()
model = torch.nn.Conv2d(2,64,kernel_size=(3,3), stride=(1,1),padding=(1,1))
model.to(device)
del model
gc.collect()
torch.cuda.empty_cache()
#used =  torch.cuda.memory_summary(device=None, abbreviated=False)
#print(used)
# Out:
# 223363
# [3.43968769730662, 1.4098885283981164]

# %% [markdown]
# ## set batch size and lr random seed

# %% [markdown]
# ## creates a namespace requried for the custome sheduler (timm module)

# %%
class Namespace:
    def __init__(self, **kwargs):
        self.lr_k_decay=1.0
        self.__dict__.update(kwargs)

# %% [markdown]
# #**FILE PATHS**
# ## important to set this to where you want to save models

# %%
# set to where you want to save models (keep using Path as this creates objects)
# Path objects used later in code 
did = Path('drive/MyDrive/0.AVA/results/training_eq_conditions/')
if not did.exists():
  did.mkdir()
res_did = Path('drive/MyDrive/0.AVA/results/')
trained = [sub_dir.name for dir in did.iterdir() for sub_dir in dir.iterdir()]

# %% [markdown]
# ### shows modesle locaiton by name add or take away models form timm availble models

# %%
avail_pretrained_models = timm.list_models(pretrained=True)
nets = [net for net in avail_pretrained_models if 'mobilevit' in net and 'tf' not in net and 'rw' not in net]

nets=[nets[-1]]
nets
# Out:
# ['mobilevit_xxs']

# %%
model_locations = {net:did/net for net in nets}
model_location = {key:Path(model_locations[key]) for key in model_locations}

# %%
# !ls drive/MyDrive/0.AVA/results/training_eq_conditions/mobilevit_s/mobilevit_s
# Out:
# ls: cannot access 'drive/MyDrive/0.AVA/results/training_eq_conditions/mobilevit_s/mobilevit_s': No such file or directory

# %%
loaded = torch.load('drive/MyDrive/0.AVA/results/training_eq_conditions/mobilevit_s/mobilevit_s')
model = timm.create_model('mobilevit_xxs')
feature_in = model.head.features_in=2
model.load_state_dict(loaded['model_state_dict'])
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-61-a93a8550d81b> in <module>()
# ----> 1 loaded = torch.load('drive/MyDrive/0.AVA/results/training_eq_conditions/mobilevit_s/mobilevit_s')
#       2 model = timm.create_model('mobilevit_s')
#       3 feature_in = model.head.features_in=2
#       4 model.load_state_dict(loaded['model_state_dict'])
#
# /usr/local/lib/python3.7/dist-packages/torch/serialization.py in load(f, map_location, pickle_module, **pickle_load_args)
#     697         pickle_load_args['encoding'] = 'utf-8'
#     698
# --> 699     with _open_file_like(f, 'rb') as opened_file:
#     700         if _is_zipfile(opened_file):
#     701             # The zipfile reader is going to advance the current file position.
#
# /usr/local/lib/python3.7/dist-packages/torch/serialization.py in _open_file_like(name_or_buffer, mode)
#     229 def _open_file_like(name_or_buffer, mode):
#     230     if _is_path(name_or_buffer):
# --> 231         return _open_file(name_or_buffer, mode)
#     232     else:
#     233         if 'w' in mode:
#
# /usr/local/lib/python3.7/dist-packages/torch/serialization.py in __init__(self, name, mode)
#     210 class _open_file(_opener):
#     211     def __init__(self, name, mode):
# --> 212         super(_open_file, self).__init__(open(name, mode))
#     213
#     214     def __exit__(self, *args):
#
# FileNotFoundError: [Errno 2] No such file or directory: 'drive/MyDrive/0.AVA/results/training_eq_conditions/mobilevit_s/mobilevit_s'

# %%
def read_json(path):
    with open(path,'r') as fid:
        try:
            data = json.load(fid)
        except:
            data = {'json missread':fid.readlines()}
        return data
def get_epochs(path):
    if path.exists():
        epochs = len([int(i.name.strip(i.suffix)[-1]) for i in path.iterdir()
        if i.suffix == '.json'])
        print(epochs)
    else:
        os.makedirs(path,exist_ok=True)
        epochs = 0
    return 10-epochs

not_train = ['Net', 'CvT','Copy', 'res','over']
still_to_train = {key:model_location[key] for key in model_location if
not any([i in key for i in not_train])
}
still_to_train = {i:{'epochs':get_epochs(still_to_train[i]),'location':still_to_train[i]} 
          for i in still_to_train}
still_to_train
# Out:
# 1
# {'mobilevit_xxs': {'epochs': 9,
#   'location': PosixPath('drive/MyDrive/0.AVA/results/training_eq_conditions/mobilevit_xxs')}}

# %%
models = {key:{'epochs':still_to_train[key], 'location':model_locations[key]} for key in still_to_train}
# creates a generator with all above models. 
mods = loader(still_to_train)

# %% [markdown]
# ## a hack cell to skip any models that you migh need to witout editing above code

# %%
models['mobilevit_xxs']
# Out:
# {'mobilevit_xxs': {'epochs': {'epochs': 9,
#    'location': PosixPath('drive/MyDrive/0.AVA/results/training_eq_conditions/mobilevit_xxs')},
#   'location': PosixPath('drive/MyDrive/0.AVA/results/training_eq_conditions/mobilevit_xxs')}}

# %%
sweep_config = {
    'method': 'random'
    }

# %%
parameters_dict = {
    'optimizer': {
        'values': ['adamW', 'adam']
        },
    'sched': {'values':['cosine','tanh']
      }
    }

sweep_config['parameters'] = parameters_dict

parameters_dict.update({
    'learning_rate': {
        # a flat distribution between 0 and 0.1
        'distribution': 'uniform',
        'min': 0,
        'max': 0.005
      },
      'warmup_lr': {
        # a flat distribution between 0 and 0.1
        'distribution': 'uniform',
        'min': 0.0001,
        'max': 0.001
      },
    'batch_size': {
        # integers between 32 and 256
        # with evenly-distributed logarithms 
        'distribution': 'q_log_uniform_values',
        'q': 8,
        'min': 32,
        'max': 128,
      },
    'decay_rate': {
        # integers between 32 and 256
        # with evenly-distributed logarithms 
        'distribution': 'uniform',
        'min': 0.0001,
        'max': 0.001
      },
       'warmup_epochs': {
        # integers between 32 and 256
        # with evenly-distributed logarithms 
        'distribution': 'q_log_uniform_values',
        'q': 2,
        'min': 2,
        'max': 10,
      },
    })
parameters_dict.update({
    'epochs': {
        'value': 10}
    })

# %%
sweep_id = wandb.sweep(sweep_config, project='small_is_beautiful',entity='iaqa')
# Out:
# Create sweep with ID: kve6igp6
# Sweep URL: https://wandb.ai/iaqa/small_is_beautiful/sweeps/kve6igp6

# %% [markdown]
# ## Training Cell

# %%
def train(config = None):
    
  
    for model,epochs,name in mods:
        print(f'model = {name} will be trained for {epochs} epochs')
        with wandb.init(config=config,save_code=True, 
                name=name):
            config = wandb.config
            print(config)
        
            if epochs>0:
                reflect_transforms = data_transforms(size=224)
                gc.collect()
                torch.cuda.empty_cache()
                print(name)
                warm_epochs = 10
                if epochs <=warm_epochs:
                    warm_epochs-=epochs
                torch.clear_autocast_cache()
                torch.cuda.empty_cache()
                gc.collect()
                model.to(device)
                
                criterion = nn.CrossEntropyLoss()
                # optimizer
                if config.optimizer =='adamW':
                    optimizer = optim.AdamW(model.parameters(), lr=config.learning_rate
                                        )
                else:
                    optimizer = optim.Adam(model.parameters(), lr=config.learning_rate
                                        )

                # scheduler
                args = Namespace(min_lr=0.0001, 
                                cooldown_epochs=0,
                                warmup_epochs=warm_epochs,
                                decay_rate=0.0001,
                                warmup_lr=config.warmup_lr, 
                                epochs=config.epochs, 
                                sched=config.sched)
              
                wandb.watch(model)
                scheduler = create_scheduler(args,optimizer)
                train_model(model, criterion, 
                            optimizer, scheduler,
                            data = data, 
                            num_epochs=epochs, 
                            model_name = name, 
                            did = did)

# %%
wandb.agent(sweep_id, train,count=100)
# Out:
# wandb: Agent Starting Run: 05h3328f with config:
# wandb: 	batch_size: 112
# wandb: 	decay_rate: 0.0089
# wandb: 	epochs: 10
# wandb: 	learning_rate: 0.0029
# wandb: 	optimizer: adam
# wandb: 	sched: cosine
# wandb: 	warmup_epochs: 8
# wandb: 	warmup_lr: 0.0032
# mobilevit_xxs
# mobilevit_xxs
# model = mobilevit_xxs will be trained for 10 epochs
# wandb: Currently logged in as: frds (iaqa). Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.12.16
# Run data is saved locally in <code>/content/wandb/run-20220516_155105-05h3328f</code>
# Syncing run <strong><a href="https://wandb.ai/iaqa/small_is_beautiful/runs/05h3328f" target="_blank">mobilevit_xxs</a></strong> to <a href="https://wandb.ai/iaqa/small_is_beautiful" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>Sweep page:  <a href="https://wandb.ai/iaqa/small_is_beautiful/sweeps/9imn7g9l" target="_blank">https://wandb.ai/iaqa/small_is_beautiful/sweeps/9imn7g9l</a>
# /usr/local/lib/python3.7/dist-packages/albumentations/augmentations/transforms.py:691: FutureWarning: This class has been deprecated. Please use CoarseDropout
#   FutureWarning,
# {'batch_size': 112, 'decay_rate': 0.0089, 'epochs': 10, 'learning_rate': 0.0029, 'optimizer': 'adam', 'sched': 'cosine', 'warmup_epochs': 8, 'warmup_lr': 0.0032}
# mobilevit_xxs
# currently trianing mobilevit_xxs
# mobilevit_xxs will be saved at drive/MyDrive/0.AVA/results/sweep/mobilevit_xxs/mobilevit_xxs
# Epoch 0/9
# ----------
# 223363
# training
# 100%|██████████| 1746/1746 [49:28<00:00,  1.70s/it]
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1987: UserWarning: y_pred contains classes not in y_true
#   warnings.warn("y_pred contains classes not in y_true")
# training Loss: 0.7011 Acc: 0.5570
# {'epoch_1_training': {'training loss': 0.7011394681686768, 'training acc': 0.5569588517346203, 'training ballance_acc': 0.3333333333333333}}
# 11758
# validation
# 100%|██████████| 92/92 [01:52<00:00,  1.23s/it]
# validation Loss: 0.7479 Acc: 0.4174
# {'epoch_1_training': {'training loss': 0.7011394681686768, 'training acc': 0.5569588517346203, 'training ballance_acc': 0.3333333333333333}, 'epoch_1_validation': {'validation loss': 0.7479100972540749, 'validation acc': 0.41741792821908486, 'validation ballance_acc': 0.5227272727272727}}
# Saving mobilevit_xxs in mobilevit_xxs
# Epoch 1/9
# ----------
# 223363
# training
# 100%|██████████| 1746/1746 [49:22<00:00,  1.70s/it]
# training Loss: 0.6559 Acc: 0.6096
# {'epoch_1_training': {'training loss': 0.7011394681686768, 'training acc': 0.5569588517346203, 'training ballance_acc': 0.3333333333333333}, 'epoch_1_validation': {'validation loss': 0.7479100972540749, 'validation acc': 0.41741792821908486, 'validation ballance_acc': 0.5227272727272727}, 'epoch_2_training': {'training loss': 0.6558950221157, 'training acc': 0.6096040973661708, 'training ballance_acc': 0.75}}
# 11758
# validation
# 100%|██████████| 92/92 [01:48<00:00,  1.18s/it]
# validation Loss: 0.6195 Acc: 0.6511
# {'epoch_1_training': {'training loss': 0.7011394681686768, 'training acc': 0.5569588517346203, 'training ballance_acc': 0.3333333333333333}, 'epoch_1_validation': {'validation loss': 0.7479100972540749, 'validation acc': 0.41741792821908486, 'validation ballance_acc': 0.5227272727272727}, 'epoch_2_training': {'training loss': 0.6558950221157, 'training acc': 0.6096040973661708, 'training ballance_acc': 0.75}, 'epoch_2_validation': {'validation loss': 0.6194931731213515, 'validation acc': 0.6511311447525089, 'validation ballance_acc': 0.5170454545454546}}
# Saving mobilevit_xxs in mobilevit_xxs
# Epoch 2/9
# ----------
# 223363
# training
# 100%|██████████| 1746/1746 [49:18<00:00,  1.69s/it]
# training Loss: 0.6507 Acc: 0.6155
# {'epoch_1_training': {'training loss': 0.7011394681686768, 'training acc': 0.5569588517346203, 'training ballance_acc': 0.3333333333333333}, 'epoch_1_validation': {'validation loss': 0.7479100972540749, 'validation acc': 0.41741792821908486, 'validation ballance_acc': 0.5227272727272727}, 'epoch_2_training': {'training loss': 0.6558950221157, 'training acc': 0.6096040973661708, 'training ballance_acc': 0.75}, 'epoch_2_validation': {'validation loss': 0.6194931731213515, 'validation acc': 0.6511311447525089, 'validation ballance_acc': 0.5170454545454546}, 'epoch_3_training': {'training loss': 0.650709304850057, 'training acc': 0.6155137601124627, 'training ballance_acc': 0.25}}
# 11758
# validation
# 100%|██████████| 92/92 [01:48<00:00,  1.18s/it]
# validation Loss: 0.6296 Acc: 0.6328
# {'epoch_1_training': {'training loss': 0.7011394681686768, 'training acc': 0.5569588517346203, 'training ballance_acc': 0.3333333333333333}, 'epoch_1_validation': {'validation loss': 0.7479100972540749, 'validation acc': 0.41741792821908486, 'validation ballance_acc': 0.5227272727272727}, 'epoch_2_training': {'training loss': 0.6558950221157, 'training acc': 0.6096040973661708, 'training ballance_acc': 0.75}, 'epoch_2_validation': {'validation loss': 0.6194931731213515, 'validation acc': 0.6511311447525089, 'validation ballance_acc': 0.5170454545454546}, 'epoch_3_training': {'training loss': 0.650709304850057, 'training acc': 0.6155137601124627, 'training ballance_acc': 0.25}, 'epoch_3_validation': {'validation loss': 0.6296493171287001, 'validation acc': 0.6328457220615751, 'validation ballance_acc': 0.5511363636363636}}
# Epoch 3/9
# ----------
# 223363
# training
# 100%|██████████| 1746/1746 [49:09<00:00,  1.69s/it]
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1987: UserWarning: y_pred contains classes not in y_true
#   warnings.warn("y_pred contains classes not in y_true")
# training Loss: 0.6464 Acc: 0.6208
# {'epoch_1_training': {'training loss': 0.7011394681686768, 'training acc': 0.5569588517346203, 'training ballance_acc': 0.3333333333333333}, 'epoch_1_validation': {'validation loss': 0.7479100972540749, 'validation acc': 0.41741792821908486, 'validation ballance_acc': 0.5227272727272727}, 'epoch_2_training': {'training loss': 0.6558950221157, 'training acc': 0.6096040973661708, 'training ballance_acc': 0.75}, 'epoch_2_validation': {'validation loss': 0.6194931731213515, 'validation acc': 0.6511311447525089, 'validation ballance_acc': 0.5170454545454546}, 'epoch_3_training': {'training loss': 0.650709304850057, 'training acc': 0.6155137601124627, 'training ballance_acc': 0.25}, 'epoch_3_validation': {'validation loss': 0.6296493171287001, 'validation acc': 0.6328457220615751, 'validation ballance_acc': 0.5511363636363636}, 'epoch_4_training': {'training loss': 0.6463766964722557, 'training acc': 0.6208414106185896, 'training ballance_acc': 0.3333333333333333}}
# 11758
# validation
# 100%|██████████| 92/92 [01:48<00:00,  1.18s/it]
# validation Loss: 0.5988 Acc: 0.6709
# {'epoch_1_training': {'training loss': 0.7011394681686768, 'training acc': 0.5569588517346203, 'training ballance_acc': 0.3333333333333333}, 'epoch_1_validation': {'validation loss': 0.7479100972540749, 'validation acc': 0.41741792821908486, 'validation ballance_acc': 0.5227272727272727}, 'epoch_2_training': {'training loss': 0.6558950221157, 'training acc': 0.6096040973661708, 'training ballance_acc': 0.75}, 'epoch_2_validation': {'validation loss': 0.6194931731213515, 'validation acc': 0.6511311447525089, 'validation ballance_acc': 0.5170454545454546}, 'epoch_3_training': {'training loss': 0.650709304850057, 'training acc': 0.6155137601124627, 'training ballance_acc': 0.25}, 'epoch_3_validation': {'validation loss': 0.6296493171287001, 'validation acc': 0.6328457220615751, 'validation ballance_acc': 0.5511363636363636}, 'epoch_4_training': {'training loss': 0.6463766964722557, 'training acc': 0.6208414106185896, 'training ballance_acc': 0.3333333333333333}, 'epoch_4_validation': {'validation loss': 0.5988314409689101, 'validation acc': 0.6708623915631909, 'validation ballance_acc': 0.5681818181818181}}
# Saving mobilevit_xxs in mobilevit_xxs
# Epoch 4/9
# ----------
# 223363
# training
# 100%|██████████| 1746/1746 [49:02<00:00,  1.69s/it]
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1987: UserWarning: y_pred contains classes not in y_true
#   warnings.warn("y_pred contains classes not in y_true")
# training Loss: 0.6440 Acc: 0.6239
# {'epoch_1_training': {'training loss': 0.7011394681686768, 'training acc': 0.5569588517346203, 'training ballance_acc': 0.3333333333333333}, 'epoch_1_validation': {'validation loss': 0.7479100972540749, 'validation acc': 0.41741792821908486, 'validation ballance_acc': 0.5227272727272727}, 'epoch_2_training': {'training loss': 0.6558950221157, 'training acc': 0.6096040973661708, 'training ballance_acc': 0.75}, 'epoch_2_validation': {'validation loss': 0.6194931731213515, 'validation acc': 0.6511311447525089, 'validation ballance_acc': 0.5170454545454546}, 'epoch_3_training': {'training loss': 0.650709304850057, 'training acc': 0.6155137601124627, 'training ballance_acc': 0.25}, 'epoch_3_validation': {'validation loss': 0.6296493171287001, 'validation acc': 0.6328457220615751, 'validation ballance_acc': 0.5511363636363636}, 'epoch_4_training': {'training loss': 0.6463766964722557, 'training acc': 0.6208414106185896, 'training ballance_acc': 0.3333333333333333}, 'epoch_4_validation': {'validation loss': 0.5988314409689101, 'validation acc': 0.6708623915631909, 'validation ballance_acc': 0.5681818181818181}, 'epoch_5_training': {'training loss': 0.643976448676206, 'training acc': 0.6239350295259287, 'training ballance_acc': 0.6666666666666666}}
# 11758
# validation
# 100%|██████████| 92/92 [01:48<00:00,  1.18s/it]
# validation Loss: 0.6187 Acc: 0.6486
# {'epoch_1_training': {'training loss': 0.7011394681686768, 'training acc': 0.5569588517346203, 'training ballance_acc': 0.3333333333333333}, 'epoch_1_validation': {'validation loss': 0.7479100972540749, 'validation acc': 0.41741792821908486, 'validation ballance_acc': 0.5227272727272727}, 'epoch_2_training': {'training loss': 0.6558950221157, 'training acc': 0.6096040973661708, 'training ballance_acc': 0.75}, 'epoch_2_validation': {'validation loss': 0.6194931731213515, 'validation acc': 0.6511311447525089, 'validation ballance_acc': 0.5170454545454546}, 'epoch_3_training': {'training loss': 0.650709304850057, 'training acc': 0.6155137601124627, 'training ballance_acc': 0.25}, 'epoch_3_validation': {'validation loss': 0.6296493171287001, 'validation acc': 0.6328457220615751, 'validation ballance_acc': 0.5511363636363636}, 'epoch_4_training': {'training loss': 0.6463766964722557, 'training acc': 0.6208414106185896, 'training ballance_acc': 0.3333333333333333}, 'epoch_4_validation': {'validation loss': 0.5988314409689101, 'validation acc': 0.6708623915631909, 'validation ballance_acc': 0.5681818181818181}, 'epoch_5_training': {'training loss': 0.643976448676206, 'training acc': 0.6239350295259287, 'training ballance_acc': 0.6666666666666666}, 'epoch_5_validation': {'validation loss': 0.6187162310376746, 'validation acc': 0.6485796904235414, 'validation ballance_acc': 0.5909090909090909}}
# Epoch 5/9
# ----------
# 223363
# training
# 100%|██████████| 1746/1746 [48:11<00:00,  1.66s/it]
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1987: UserWarning: y_pred contains classes not in y_true
#   warnings.warn("y_pred contains classes not in y_true")
# training Loss: 0.6394 Acc: 0.6292
# {'epoch_1_training': {'training loss': 0.7011394681686768, 'training acc': 0.5569588517346203, 'training ballance_acc': 0.3333333333333333}, 'epoch_1_validation': {'validation loss': 0.7479100972540749, 'validation acc': 0.41741792821908486, 'validation ballance_acc': 0.5227272727272727}, 'epoch_2_training': {'training loss': 0.6558950221157, 'training acc': 0.6096040973661708, 'training ballance_acc': 0.75}, 'epoch_2_validation': {'validation loss': 0.6194931731213515, 'validation acc': 0.6511311447525089, 'validation ballance_acc': 0.5170454545454546}, 'epoch_3_training': {'training loss': 0.650709304850057, 'training acc': 0.6155137601124627, 'training ballance_acc': 0.25}, 'epoch_3_validation': {'validation loss': 0.6296493171287001, 'validation acc': 0.6328457220615751, 'validation ballance_acc': 0.5511363636363636}, 'epoch_4_training': {'training loss': 0.6463766964722557, 'training acc': 0.6208414106185896, 'training ballance_acc': 0.3333333333333333}, 'epoch_4_validation': {'validation loss': 0.5988314409689101, 'validation acc': 0.6708623915631909, 'validation ballance_acc': 0.5681818181818181}, 'epoch_5_training': {'training loss': 0.643976448676206, 'training acc': 0.6239350295259287, 'training ballance_acc': 0.6666666666666666}, 'epoch_5_validation': {'validation loss': 0.6187162310376746, 'validation acc': 0.6485796904235414, 'validation ballance_acc': 0.5909090909090909}, 'epoch_6_training': {'training loss': 0.6393585518393247, 'training acc': 0.6291641856529506, 'training ballance_acc': 0.6666666666666666}}
# 11758
# validation
# 100%|██████████| 92/92 [01:47<00:00,  1.17s/it]
# validation Loss: 0.5926 Acc: 0.6770
# {'epoch_1_training': {'training loss': 0.7011394681686768, 'training acc': 0.5569588517346203, 'training ballance_acc': 0.3333333333333333}, 'epoch_1_validation': {'validation loss': 0.7479100972540749, 'validation acc': 0.41741792821908486, 'validation ballance_acc': 0.5227272727272727}, 'epoch_2_training': {'training loss': 0.6558950221157, 'training acc': 0.6096040973661708, 'training ballance_acc': 0.75}, 'epoch_2_validation': {'validation loss': 0.6194931731213515, 'validation acc': 0.6511311447525089, 'validation ballance_acc': 0.5170454545454546}, 'epoch_3_training': {'training loss': 0.650709304850057, 'training acc': 0.6155137601124627, 'training ballance_acc': 0.25}, 'epoch_3_validation': {'validation loss': 0.6296493171287001, 'validation acc': 0.6328457220615751, 'validation ballance_acc': 0.5511363636363636}, 'epoch_4_training': {'training loss': 0.6463766964722557, 'training acc': 0.6208414106185896, 'training ballance_acc': 0.3333333333333333}, 'epoch_4_validation': {'validation loss': 0.5988314409689101, 'validation acc': 0.6708623915631909, 'validation ballance_acc': 0.5681818181818181}, 'epoch_5_training': {'training loss': 0.643976448676206, 'training acc': 0.6239350295259287, 'training ballance_acc': 0.6666666666666666}, 'epoch_5_validation': {'validation loss': 0.6187162310376746, 'validation acc': 0.6485796904235414, 'validation ballance_acc': 0.5909090909090909}, 'epoch_6_training': {'training loss': 0.6393585518393247, 'training acc': 0.6291641856529506, 'training ballance_acc': 0.6666666666666666}, 'epoch_6_validation': {'validation loss': 0.5925728581575821, 'validation acc': 0.676985881952713, 'validation ballance_acc': 0.5568181818181819}}
# Saving mobilevit_xxs in mobilevit_xxs
# Epoch 6/9
# ----------
# 223363
# training
# 100%|██████████| 1746/1746 [48:22<00:00,  1.66s/it]
# training Loss: 0.6357 Acc: 0.6333
# {'epoch_1_training': {'training loss': 0.7011394681686768, 'training acc': 0.5569588517346203, 'training ballance_acc': 0.3333333333333333}, 'epoch_1_validation': {'validation loss': 0.7479100972540749, 'validation acc': 0.41741792821908486, 'validation ballance_acc': 0.5227272727272727}, 'epoch_2_training': {'training loss': 0.6558950221157, 'training acc': 0.6096040973661708, 'training ballance_acc': 0.75}, 'epoch_2_validation': {'validation loss': 0.6194931731213515, 'validation acc': 0.6511311447525089, 'validation ballance_acc': 0.5170454545454546}, 'epoch_3_training': {'training loss': 0.650709304850057, 'training acc': 0.6155137601124627, 'training ballance_acc': 0.25}, 'epoch_3_validation': {'validation loss': 0.6296493171287001, 'validation acc': 0.6328457220615751, 'validation ballance_acc': 0.5511363636363636}, 'epoch_4_training': {'training loss': 0.6463766964722557, 'training acc': 0.6208414106185896, 'training ballance_acc': 0.3333333333333333}, 'epoch_4_validation': {'validation loss': 0.5988314409689101, 'validation acc': 0.6708623915631909, 'validation ballance_acc': 0.5681818181818181}, 'epoch_5_training': {'training loss': 0.643976448676206, 'training acc': 0.6239350295259287, 'training ballance_acc': 0.6666666666666666}, 'epoch_5_validation': {'validation loss': 0.6187162310376746, 'validation acc': 0.6485796904235414, 'validation ballance_acc': 0.5909090909090909}, 'epoch_6_training': {'training loss': 0.6393585518393247, 'training acc': 0.6291641856529506, 'training ballance_acc': 0.6666666666666666}, 'epoch_6_validation': {'validation loss': 0.5925728581575821, 'validation acc': 0.676985881952713, 'validation ballance_acc': 0.5568181818181819}, 'epoch_7_training': {'training loss': 0.6356803572835461, 'training acc': 0.6332919955408909, 'training ballance_acc': 0.75}}
# 11758
# validation
# 100%|██████████| 92/92 [01:48<00:00,  1.18s/it]
# validation Loss: 0.5946 Acc: 0.6753
# {'epoch_1_training': {'training loss': 0.7011394681686768, 'training acc': 0.5569588517346203, 'training ballance_acc': 0.3333333333333333}, 'epoch_1_validation': {'validation loss': 0.7479100972540749, 'validation acc': 0.41741792821908486, 'validation ballance_acc': 0.5227272727272727}, 'epoch_2_training': {'training loss': 0.6558950221157, 'training acc': 0.6096040973661708, 'training ballance_acc': 0.75}, 'epoch_2_validation': {'validation loss': 0.6194931731213515, 'validation acc': 0.6511311447525089, 'validation ballance_acc': 0.5170454545454546}, 'epoch_3_training': {'training loss': 0.650709304850057, 'training acc': 0.6155137601124627, 'training ballance_acc': 0.25}, 'epoch_3_validation': {'validation loss': 0.6296493171287001, 'validation acc': 0.6328457220615751, 'validation ballance_acc': 0.5511363636363636}, 'epoch_4_training': {'training loss': 0.6463766964722557, 'training acc': 0.6208414106185896, 'training ballance_acc': 0.3333333333333333}, 'epoch_4_validation': {'validation loss': 0.5988314409689101, 'validation acc': 0.6708623915631909, 'validation ballance_acc': 0.5681818181818181}, 'epoch_5_training': {'training loss': 0.643976448676206, 'training acc': 0.6239350295259287, 'training ballance_acc': 0.6666666666666666}, 'epoch_5_validation': {'validation loss': 0.6187162310376746, 'validation acc': 0.6485796904235414, 'validation ballance_acc': 0.5909090909090909}, 'epoch_6_training': {'training loss': 0.6393585518393247, 'training acc': 0.6291641856529506, 'training ballance_acc': 0.6666666666666666}, 'epoch_6_validation': {'validation loss': 0.5925728581575821, 'validation acc': 0.676985881952713, 'validation ballance_acc': 0.5568181818181819}, 'epoch_7_training': {'training loss': 0.6356803572835461, 'training acc': 0.6332919955408909, 'training ballance_acc': 0.75}, 'epoch_7_validation': {'validation loss': 0.5945739418820756, 'validation acc': 0.6752849124000679, 'validation ballance_acc': 0.5965909090909091}}
# Epoch 7/9
# ----------
# 223363
# training
# 100%|██████████| 1746/1746 [47:17<00:00,  1.63s/it]
# training Loss: 0.6337 Acc: 0.6355
# {'epoch_1_training': {'training loss': 0.7011394681686768, 'training acc': 0.5569588517346203, 'training ballance_acc': 0.3333333333333333}, 'epoch_1_validation': {'validation loss': 0.7479100972540749, 'validation acc': 0.41741792821908486, 'validation ballance_acc': 0.5227272727272727}, 'epoch_2_training': {'training loss': 0.6558950221157, 'training acc': 0.6096040973661708, 'training ballance_acc': 0.75}, 'epoch_2_validation': {'validation loss': 0.6194931731213515, 'validation acc': 0.6511311447525089, 'validation ballance_acc': 0.5170454545454546}, 'epoch_3_training': {'training loss': 0.650709304850057, 'training acc': 0.6155137601124627, 'training ballance_acc': 0.25}, 'epoch_3_validation': {'validation loss': 0.6296493171287001, 'validation acc': 0.6328457220615751, 'validation ballance_acc': 0.5511363636363636}, 'epoch_4_training': {'training loss': 0.6463766964722557, 'training acc': 0.6208414106185896, 'training ballance_acc': 0.3333333333333333}, 'epoch_4_validation': {'validation loss': 0.5988314409689101, 'validation acc': 0.6708623915631909, 'validation ballance_acc': 0.5681818181818181}, 'epoch_5_training': {'training loss': 0.643976448676206, 'training acc': 0.6239350295259287, 'training ballance_acc': 0.6666666666666666}, 'epoch_5_validation': {'validation loss': 0.6187162310376746, 'validation acc': 0.6485796904235414, 'validation ballance_acc': 0.5909090909090909}, 'epoch_6_training': {'training loss': 0.6393585518393247, 'training acc': 0.6291641856529506, 'training ballance_acc': 0.6666666666666666}, 'epoch_6_validation': {'validation loss': 0.5925728581575821, 'validation acc': 0.676985881952713, 'validation ballance_acc': 0.5568181818181819}, 'epoch_7_training': {'training loss': 0.6356803572835461, 'training acc': 0.6332919955408909, 'training ballance_acc': 0.75}, 'epoch_7_validation': {'validation loss': 0.5945739418820756, 'validation acc': 0.6752849124000679, 'validation ballance_acc': 0.5965909090909091}, 'epoch_8_training': {'training loss': 0.6336974143304932, 'training acc': 0.6355081190707503, 'training ballance_acc': 1.0}}
# 11758
# validation
# 100%|██████████| 92/92 [01:46<00:00,  1.16s/it]
# validation Loss: 0.6149 Acc: 0.6497
# {'epoch_1_training': {'training loss': 0.7011394681686768, 'training acc': 0.5569588517346203, 'training ballance_acc': 0.3333333333333333}, 'epoch_1_validation': {'validation loss': 0.7479100972540749, 'validation acc': 0.41741792821908486, 'validation ballance_acc': 0.5227272727272727}, 'epoch_2_training': {'training loss': 0.6558950221157, 'training acc': 0.6096040973661708, 'training ballance_acc': 0.75}, 'epoch_2_validation': {'validation loss': 0.6194931731213515, 'validation acc': 0.6511311447525089, 'validation ballance_acc': 0.5170454545454546}, 'epoch_3_training': {'training loss': 0.650709304850057, 'training acc': 0.6155137601124627, 'training ballance_acc': 0.25}, 'epoch_3_validation': {'validation loss': 0.6296493171287001, 'validation acc': 0.6328457220615751, 'validation ballance_acc': 0.5511363636363636}, 'epoch_4_training': {'training loss': 0.6463766964722557, 'training acc': 0.6208414106185896, 'training ballance_acc': 0.3333333333333333}, 'epoch_4_validation': {'validation loss': 0.5988314409689101, 'validation acc': 0.6708623915631909, 'validation ballance_acc': 0.5681818181818181}, 'epoch_5_training': {'training loss': 0.643976448676206, 'training acc': 0.6239350295259287, 'training ballance_acc': 0.6666666666666666}, 'epoch_5_validation': {'validation loss': 0.6187162310376746, 'validation acc': 0.6485796904235414, 'validation ballance_acc': 0.5909090909090909}, 'epoch_6_training': {'training loss': 0.6393585518393247, 'training acc': 0.6291641856529506, 'training ballance_acc': 0.6666666666666666}, 'epoch_6_validation': {'validation loss': 0.5925728581575821, 'validation acc': 0.676985881952713, 'validation ballance_acc': 0.5568181818181819}, 'epoch_7_training': {'training loss': 0.6356803572835461, 'training acc': 0.6332919955408909, 'training ballance_acc': 0.75}, 'epoch_7_validation': {'validation loss': 0.5945739418820756, 'validation acc': 0.6752849124000679, 'validation ballance_acc': 0.5965909090909091}, 'epoch_8_training': {'training loss': 0.6336974143304932, 'training acc': 0.6355081190707503, 'training ballance_acc': 1.0}, 'epoch_8_validation': {'validation loss': 0.6148706854535398, 'validation acc': 0.6496853206327606, 'validation ballance_acc': 0.5568181818181818}}
# Epoch 8/9
# ----------
# 223363
# training
# 100%|██████████| 1746/1746 [47:07<00:00,  1.62s/it]
# training Loss: 0.6319 Acc: 0.6374
# {'epoch_1_training': {'training loss': 0.7011394681686768, 'training acc': 0.5569588517346203, 'training ballance_acc': 0.3333333333333333}, 'epoch_1_validation': {'validation loss': 0.7479100972540749, 'validation acc': 0.41741792821908486, 'validation ballance_acc': 0.5227272727272727}, 'epoch_2_training': {'training loss': 0.6558950221157, 'training acc': 0.6096040973661708, 'training ballance_acc': 0.75}, 'epoch_2_validation': {'validation loss': 0.6194931731213515, 'validation acc': 0.6511311447525089, 'validation ballance_acc': 0.5170454545454546}, 'epoch_3_training': {'training loss': 0.650709304850057, 'training acc': 0.6155137601124627, 'training ballance_acc': 0.25}, 'epoch_3_validation': {'validation loss': 0.6296493171287001, 'validation acc': 0.6328457220615751, 'validation ballance_acc': 0.5511363636363636}, 'epoch_4_training': {'training loss': 0.6463766964722557, 'training acc': 0.6208414106185896, 'training ballance_acc': 0.3333333333333333}, 'epoch_4_validation': {'validation loss': 0.5988314409689101, 'validation acc': 0.6708623915631909, 'validation ballance_acc': 0.5681818181818181}, 'epoch_5_training': {'training loss': 0.643976448676206, 'training acc': 0.6239350295259287, 'training ballance_acc': 0.6666666666666666}, 'epoch_5_validation': {'validation loss': 0.6187162310376746, 'validation acc': 0.6485796904235414, 'validation ballance_acc': 0.5909090909090909}, 'epoch_6_training': {'training loss': 0.6393585518393247, 'training acc': 0.6291641856529506, 'training ballance_acc': 0.6666666666666666}, 'epoch_6_validation': {'validation loss': 0.5925728581575821, 'validation acc': 0.676985881952713, 'validation ballance_acc': 0.5568181818181819}, 'epoch_7_training': {'training loss': 0.6356803572835461, 'training acc': 0.6332919955408909, 'training ballance_acc': 0.75}, 'epoch_7_validation': {'validation loss': 0.5945739418820756, 'validation acc': 0.6752849124000679, 'validation ballance_acc': 0.5965909090909091}, 'epoch_8_training': {'training loss': 0.6336974143304932, 'training acc': 0.6355081190707503, 'training ballance_acc': 1.0}, 'epoch_8_validation': {'validation loss': 0.6148706854535398, 'validation acc': 0.6496853206327606, 'validation ballance_acc': 0.5568181818181818}, 'epoch_9_training': {'training loss': 0.6318900999687596, 'training acc': 0.6373974203426709, 'training ballance_acc': 1.0}}
# 11758
# validation
# 100%|██████████| 92/92 [01:46<00:00,  1.16s/it]
# validation Loss: 0.5793 Acc: 0.6897
# {'epoch_1_training': {'training loss': 0.7011394681686768, 'training acc': 0.5569588517346203, 'training ballance_acc': 0.3333333333333333}, 'epoch_1_validation': {'validation loss': 0.7479100972540749, 'validation acc': 0.41741792821908486, 'validation ballance_acc': 0.5227272727272727}, 'epoch_2_training': {'training loss': 0.6558950221157, 'training acc': 0.6096040973661708, 'training ballance_acc': 0.75}, 'epoch_2_validation': {'validation loss': 0.6194931731213515, 'validation acc': 0.6511311447525089, 'validation ballance_acc': 0.5170454545454546}, 'epoch_3_training': {'training loss': 0.650709304850057, 'training acc': 0.6155137601124627, 'training ballance_acc': 0.25}, 'epoch_3_validation': {'validation loss': 0.6296493171287001, 'validation acc': 0.6328457220615751, 'validation ballance_acc': 0.5511363636363636}, 'epoch_4_training': {'training loss': 0.6463766964722557, 'training acc': 0.6208414106185896, 'training ballance_acc': 0.3333333333333333}, 'epoch_4_validation': {'validation loss': 0.5988314409689101, 'validation acc': 0.6708623915631909, 'validation ballance_acc': 0.5681818181818181}, 'epoch_5_training': {'training loss': 0.643976448676206, 'training acc': 0.6239350295259287, 'training ballance_acc': 0.6666666666666666}, 'epoch_5_validation': {'validation loss': 0.6187162310376746, 'validation acc': 0.6485796904235414, 'validation ballance_acc': 0.5909090909090909}, 'epoch_6_training': {'training loss': 0.6393585518393247, 'training acc': 0.6291641856529506, 'training ballance_acc': 0.6666666666666666}, 'epoch_6_validation': {'validation loss': 0.5925728581575821, 'validation acc': 0.676985881952713, 'validation ballance_acc': 0.5568181818181819}, 'epoch_7_training': {'training loss': 0.6356803572835461, 'training acc': 0.6332919955408909, 'training ballance_acc': 0.75}, 'epoch_7_validation': {'validation loss': 0.5945739418820756, 'validation acc': 0.6752849124000679, 'validation ballance_acc': 0.5965909090909091}, 'epoch_8_training': {'training loss': 0.6336974143304932, 'training acc': 0.6355081190707503, 'training ballance_acc': 1.0}, 'epoch_8_validation': {'validation loss': 0.6148706854535398, 'validation acc': 0.6496853206327606, 'validation ballance_acc': 0.5568181818181818}, 'epoch_9_training': {'training loss': 0.6318900999687596, 'training acc': 0.6373974203426709, 'training ballance_acc': 1.0}, 'epoch_9_validation': {'validation loss': 0.5793006040953033, 'validation acc': 0.6896581051199183, 'validation ballance_acc': 0.48863636363636365}}
# Saving mobilevit_xxs in mobilevit_xxs
# Epoch 9/9
# ----------
# 223363
# training
# 100%|██████████| 1746/1746 [47:06<00:00,  1.62s/it]
# training Loss: 0.6307 Acc: 0.6392
# {'epoch_1_training': {'training loss': 0.7011394681686768, 'training acc': 0.5569588517346203, 'training ballance_acc': 0.3333333333333333}, 'epoch_1_validation': {'validation loss': 0.7479100972540749, 'validation acc': 0.41741792821908486, 'validation ballance_acc': 0.5227272727272727}, 'epoch_2_training': {'training loss': 0.6558950221157, 'training acc': 0.6096040973661708, 'training ballance_acc': 0.75}, 'epoch_2_validation': {'validation loss': 0.6194931731213515, 'validation acc': 0.6511311447525089, 'validation ballance_acc': 0.5170454545454546}, 'epoch_3_training': {'training loss': 0.650709304850057, 'training acc': 0.6155137601124627, 'training ballance_acc': 0.25}, 'epoch_3_validation': {'validation loss': 0.6296493171287001, 'validation acc': 0.6328457220615751, 'validation ballance_acc': 0.5511363636363636}, 'epoch_4_training': {'training loss': 0.6463766964722557, 'training acc': 0.6208414106185896, 'training ballance_acc': 0.3333333333333333}, 'epoch_4_validation': {'validation loss': 0.5988314409689101, 'validation acc': 0.6708623915631909, 'validation ballance_acc': 0.5681818181818181}, 'epoch_5_training': {'training loss': 0.643976448676206, 'training acc': 0.6239350295259287, 'training ballance_acc': 0.6666666666666666}, 'epoch_5_validation': {'validation loss': 0.6187162310376746, 'validation acc': 0.6485796904235414, 'validation ballance_acc': 0.5909090909090909}, 'epoch_6_training': {'training loss': 0.6393585518393247, 'training acc': 0.6291641856529506, 'training ballance_acc': 0.6666666666666666}, 'epoch_6_validation': {'validation loss': 0.5925728581575821, 'validation acc': 0.676985881952713, 'validation ballance_acc': 0.5568181818181819}, 'epoch_7_training': {'training loss': 0.6356803572835461, 'training acc': 0.6332919955408909, 'training ballance_acc': 0.75}, 'epoch_7_validation': {'validation loss': 0.5945739418820756, 'validation acc': 0.6752849124000679, 'validation ballance_acc': 0.5965909090909091}, 'epoch_8_training': {'training loss': 0.6336974143304932, 'training acc': 0.6355081190707503, 'training ballance_acc': 1.0}, 'epoch_8_validation': {'validation loss': 0.6148706854535398, 'validation acc': 0.6496853206327606, 'validation ballance_acc': 0.5568181818181818}, 'epoch_9_training': {'training loss': 0.6318900999687596, 'training acc': 0.6373974203426709, 'training ballance_acc': 1.0}, 'epoch_9_validation': {'validation loss': 0.5793006040953033, 'validation acc': 0.6896581051199183, 'validation ballance_acc': 0.48863636363636365}, 'epoch_10_training': {'training loss': 0.6307360095012488, 'training acc': 0.639232997407807, 'training ballance_acc': 0.75}}
# 11758
# validation
# 100%|██████████| 92/92 [01:45<00:00,  1.15s/it]
# validation Loss: 0.5837 Acc: 0.6871
# {'epoch_1_training': {'training loss': 0.7011394681686768, 'training acc': 0.5569588517346203, 'training ballance_acc': 0.3333333333333333}, 'epoch_1_validation': {'validation loss': 0.7479100972540749, 'validation acc': 0.41741792821908486, 'validation ballance_acc': 0.5227272727272727}, 'epoch_2_training': {'training loss': 0.6558950221157, 'training acc': 0.6096040973661708, 'training ballance_acc': 0.75}, 'epoch_2_validation': {'validation loss': 0.6194931731213515, 'validation acc': 0.6511311447525089, 'validation ballance_acc': 0.5170454545454546}, 'epoch_3_training': {'training loss': 0.650709304850057, 'training acc': 0.6155137601124627, 'training ballance_acc': 0.25}, 'epoch_3_validation': {'validation loss': 0.6296493171287001, 'validation acc': 0.6328457220615751, 'validation ballance_acc': 0.5511363636363636}, 'epoch_4_training': {'training loss': 0.6463766964722557, 'training acc': 0.6208414106185896, 'training ballance_acc': 0.3333333333333333}, 'epoch_4_validation': {'validation loss': 0.5988314409689101, 'validation acc': 0.6708623915631909, 'validation ballance_acc': 0.5681818181818181}, 'epoch_5_training': {'training loss': 0.643976448676206, 'training acc': 0.6239350295259287, 'training ballance_acc': 0.6666666666666666}, 'epoch_5_validation': {'validation loss': 0.6187162310376746, 'validation acc': 0.6485796904235414, 'validation ballance_acc': 0.5909090909090909}, 'epoch_6_training': {'training loss': 0.6393585518393247, 'training acc': 0.6291641856529506, 'training ballance_acc': 0.6666666666666666}, 'epoch_6_validation': {'validation loss': 0.5925728581575821, 'validation acc': 0.676985881952713, 'validation ballance_acc': 0.5568181818181819}, 'epoch_7_training': {'training loss': 0.6356803572835461, 'training acc': 0.6332919955408909, 'training ballance_acc': 0.75}, 'epoch_7_validation': {'validation loss': 0.5945739418820756, 'validation acc': 0.6752849124000679, 'validation ballance_acc': 0.5965909090909091}, 'epoch_8_training': {'training loss': 0.6336974143304932, 'training acc': 0.6355081190707503, 'training ballance_acc': 1.0}, 'epoch_8_validation': {'validation loss': 0.6148706854535398, 'validation acc': 0.6496853206327606, 'validation ballance_acc': 0.5568181818181818}, 'epoch_9_training': {'training loss': 0.6318900999687596, 'training acc': 0.6373974203426709, 'training ballance_acc': 1.0}, 'epoch_9_validation': {'validation loss': 0.5793006040953033, 'validation acc': 0.6896581051199183, 'validation ballance_acc': 0.48863636363636365}, 'epoch_10_training': {'training loss': 0.6307360095012488, 'training acc': 0.639232997407807, 'training ballance_acc': 0.75}, 'epoch_10_validation': {'validation loss': 0.583659187063187, 'validation acc': 0.6871066507909508, 'validation ballance_acc': 0.5568181818181819}}
# training time = {'mins': 502.0, 'seconds': 29.061328172683716, 'best_acc': 0.6896581051199183, '_timestamp': 1652746422, '_runtime': 30157}
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.001 MB of 0.001 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>best_acc</td><td>▁</td></tr><tr><td>best_epoch</td><td>▁▂▄▅█</td></tr><tr><td>mins</td><td>▁</td></tr><tr><td>seconds</td><td>▁</td></tr><tr><td>training acc</td><td>▁▅▆▆▇▇▇███</td></tr><tr><td>training ballance_acc</td><td>▂▆▁▂▅▅▆██▆</td></tr><tr><td>training loss</td><td>█▄▃▃▂▂▁▁▁▁</td></tr><tr><td>validation acc</td><td>▁▇▇█▇██▇██</td></tr><tr><td>validation ballance_acc</td><td>▃▃▅▆█▅█▅▁▅</td></tr><tr><td>validation loss</td><td>█▃▃▂▃▂▂▂▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>best_acc</td><td>0.68966</td></tr><tr><td>best_epoch</td><td>8</td></tr><tr><td>mins</td><td>502.0</td></tr><tr><td>seconds</td><td>29.06133</td></tr><tr><td>training acc</td><td>0.63923</td></tr><tr><td>training ballance_acc</td><td>0.75</td></tr><tr><td>training loss</td><td>0.63074</td></tr><tr><td>validation acc</td><td>0.68711</td></tr><tr><td>validation ballance_acc</td><td>0.55682</td></tr><tr><td>validation loss</td><td>0.58366</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">mobilevit_xxs</strong>: <a href="https://wandb.ai/iaqa/small_is_beautiful/runs/05h3328f" target="_blank">https://wandb.ai/iaqa/small_is_beautiful/runs/05h3328f</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 1 other file(s)
# Find logs at: <code>./wandb/run-20220516_155105-05h3328f/logs</code>
# wandb: Sweep Agent: Waiting for job.
# wandb: Job received.
# wandb: Agent Starting Run: yky2fd33 with config:
# wandb: 	batch_size: 32
# wandb: 	decay_rate: 0.004
# wandb: 	epochs: 10
# wandb: 	learning_rate: 0.0005
# wandb: 	optimizer: adam
# wandb: 	sched: cosine
# wandb: 	warmup_epochs: 2
# wandb: 	warmup_lr: 0.0024
# wandb: Agent Starting Run: acbnhy7z with config:
# wandb: 	batch_size: 88
# wandb: 	decay_rate: 0.005
# wandb: 	epochs: 10
# wandb: 	learning_rate: 0.0024
# wandb: 	optimizer: adamW
# wandb: 	sched: cosine
# wandb: 	warmup_epochs: 2
# wandb: 	warmup_lr: 0.0036000000000000003
# wandb: Sweep Agent: Waiting for job.
# wandb: Job received.
# wandb: Agent Starting Run: h8uu71pm with config:
# wandb: 	batch_size: 80
# wandb: 	decay_rate: 0.003
# wandb: 	epochs: 10
# wandb: 	learning_rate: 0.0011
# wandb: 	optimizer: SGD
# wandb: 	sched: poly
# wandb: 	warmup_epochs: 4
# wandb: 	warmup_lr: 0.0007
# wandb: Agent Starting Run: kp5x4hoa with config:
# wandb: 	batch_size: 72
# wandb: 	decay_rate: 0.0036000000000000003
# wandb: 	epochs: 10
# wandb: 	learning_rate: 0.0016
# wandb: 	optimizer: adamW
# wandb: 	sched: cosine
# wandb: 	warmup_epochs: 2
# wandb: 	warmup_lr: 0.0008
# wandb: Sweep Agent: Waiting for job.
# wandb: Job received.
# wandb: Agent Starting Run: fnvu8s26 with config:
# wandb: 	batch_size: 40
# wandb: 	decay_rate: 0.006200000000000001
# wandb: 	epochs: 10
# wandb: 	learning_rate: 0.0008
# wandb: 	optimizer: adamW
# wandb: 	sched: poly
# wandb: 	warmup_epochs: 6
# wandb: 	warmup_lr: 0.0032
# wandb: Agent Starting Run: fab1omp4 with config:
# wandb: 	batch_size: 40
# wandb: 	decay_rate: 0.006500000000000001
# wandb: 	epochs: 10
# wandb: 	learning_rate: 0.0008
# wandb: 	optimizer: adam
# wandb: 	sched: cosine
# wandb: 	warmup_epochs: 2
# wandb: 	warmup_lr: 0.0048
# wandb: Sweep Agent: Waiting for job.
# wandb: Job received.
# wandb: Agent Starting Run: 2bn5xzez with config:
# wandb: 	batch_size: 40
# wandb: 	decay_rate: 0.0078
# wandb: 	epochs: 10
# wandb: 	learning_rate: 0.0043
# wandb: 	optimizer: adamW
# wandb: 	sched: cosine
# wandb: 	warmup_epochs: 2
# wandb: 	warmup_lr: 0.0049
# wandb: Agent Starting Run: 1usyp5fa with config:
# wandb: 	batch_size: 88
# wandb: 	decay_rate: 0.0094
# wandb: 	epochs: 10
# wandb: 	learning_rate: 0.0025
# wandb: 	optimizer: adamW
# wandb: 	sched: poly
# wandb: 	warmup_epochs: 10
# wandb: 	warmup_lr: 0.005
# wandb: Sweep Agent: Waiting for job.
# wandb: Job received.
# wandb: Agent Starting Run: sv4dolnk with config:
# wandb: 	batch_size: 72
# wandb: 	decay_rate: 0.0099
# wandb: 	epochs: 10
# wandb: 	learning_rate: 0.0033
# wandb: 	optimizer: SGD
# wandb: 	sched: tanh
# wandb: 	warmup_epochs: 8
# wandb: 	warmup_lr: 0.0046
# wandb: Agent Starting Run: fckvfzfg with config:
# wandb: 	batch_size: 80
# wandb: 	decay_rate: 0.0057
# wandb: 	epochs: 10
# wandb: 	learning_rate: 0.0011
# wandb: 	optimizer: adam
# wandb: 	sched: tanh
# wandb: 	warmup_epochs: 4
# wandb: 	warmup_lr: 0.0048
# wandb: Sweep Agent: Waiting for job.
# wandb: Job received.
# wandb: Agent Starting Run: 63s0u1dx with config:
# wandb: 	batch_size: 88
# wandb: 	decay_rate: 0.0015
# wandb: 	epochs: 10
# wandb: 	learning_rate: 0.0039
# wandb: 	optimizer: adam
# wandb: 	sched: cosine
# wandb: 	warmup_epochs: 6
# wandb: 	warmup_lr: 0.002
# wandb: Agent Starting Run: meylfqdg with config:
# wandb: 	batch_size: 112
# wandb: 	decay_rate: 0.0016
# wandb: 	epochs: 10
# wandb: 	learning_rate: 0.0021000000000000003
# wandb: 	optimizer: adamW
# wandb: 	sched: cosine
# wandb: 	warmup_epochs: 2
# wandb: 	warmup_lr: 0.0014
# wandb: Sweep Agent: Waiting for job.
# wandb: Job received.
# wandb: Agent Starting Run: 1urntgvr with config:
# wandb: 	batch_size: 112
# wandb: 	decay_rate: 0.0041
# wandb: 	epochs: 10
# wandb: 	learning_rate: 0.004
# wandb: 	optimizer: adamW
# wandb: 	sched: tanh
# wandb: 	warmup_epochs: 2
# wandb: 	warmup_lr: 0.0022
# wandb: Agent Starting Run: 83h7xofq with config:
# wandb: 	batch_size: 32
# wandb: 	decay_rate: 0.006
# wandb: 	epochs: 10
# wandb: 	learning_rate: 0.0037
# wandb: 	optimizer: adamW
# wandb: 	sched: cosine
# wandb: 	warmup_epochs: 6
# wandb: 	warmup_lr: 0.0035
# wandb: Sweep Agent: Waiting for job.
# wandb: Job received.
# wandb: Agent Starting Run: xy7tn45f with config:
# wandb: 	batch_size: 88
# wandb: 	decay_rate: 0.007200000000000001
# wandb: 	epochs: 10
# wandb: 	learning_rate: 0.0013000000000000002
# wandb: 	optimizer: SGD
# wandb: 	sched: poly
# wandb: 	warmup_epochs: 8
# wandb: 	warmup_lr: 0.0006000000000000001
# wandb: Agent Starting Run: aunq32gi with config:
# wandb: 	batch_size: 48
# wandb: 	decay_rate: 0.0074
# wandb: 	epochs: 10
# wandb: 	learning_rate: 0.0024
# wandb: 	optimizer: adam
# wandb: 	sched: poly
# wandb: 	warmup_epochs: 2
# wandb: 	warmup_lr: 0.0046
# wandb: Sweep Agent: Waiting for job.
# wandb: Job received.
# wandb: Agent Starting Run: v6sq9kwh with config:
# wandb: 	batch_size: 120
# wandb: 	decay_rate: 0.0005
# wandb: 	epochs: 10
# wandb: 	learning_rate: 0.0022
# wandb: 	optimizer: SGD
# wandb: 	sched: tanh
# wandb: 	warmup_epochs: 6
# wandb: 	warmup_lr: 0.0038
# wandb: Agent Starting Run: 16otyczm with config:
# wandb: 	batch_size: 48
# wandb: 	decay_rate: 0.0066
# wandb: 	epochs: 10
# wandb: 	learning_rate: 0.0028
# wandb: 	optimizer: SGD
# wandb: 	sched: tanh
# wandb: 	warmup_epochs: 2
# wandb: 	warmup_lr: 0.0013000000000000002
# wandb: Sweep Agent: Waiting for job.
# wandb: Job received.
# wandb: Agent Starting Run: j7d22nhd with config:
# wandb: 	batch_size: 96
# wandb: 	decay_rate: 0.0067
# wandb: 	epochs: 10
# wandb: 	learning_rate: 0.0029
# wandb: 	optimizer: adamW
# wandb: 	sched: cosine
# wandb: 	warmup_epochs: 8
# wandb: 	warmup_lr: 0.0029
# wandb: Agent Starting Run: js0ekv90 with config:
# wandb: 	batch_size: 80
# wandb: 	decay_rate: 0.0078
# wandb: 	epochs: 10
# wandb: 	learning_rate: 0.0022
# wandb: 	optimizer: adamW
# wandb: 	sched: cosine
# wandb: 	warmup_epochs: 2
# wandb: 	warmup_lr: 0.0007
# wandb: Sweep Agent: Waiting for job.
# wandb: Job received.
# wandb: Agent Starting Run: lugt1i32 with config:
# wandb: 	batch_size: 96
# wandb: 	decay_rate: 0.0029
# wandb: 	epochs: 10
# wandb: 	learning_rate: 0.0035
# wandb: 	optimizer: adamW
# wandb: 	sched: tanh
# wandb: 	warmup_epochs: 4
# wandb: 	warmup_lr: 0.004
# wandb: Agent Starting Run: r6d26a4f with config:
# wandb: 	batch_size: 56
# wandb: 	decay_rate: 0.0039
# wandb: 	epochs: 10
# wandb: 	learning_rate: 0.0014
# wandb: 	optimizer: adam
# wandb: 	sched: cosine
# wandb: 	warmup_epochs: 4
# wandb: 	warmup_lr: 0.0045000000000000005
# wandb: Sweep Agent: Waiting for job.
# wandb: Job received.
# wandb: Agent Starting Run: dkxb1ybw with config:
# wandb: 	batch_size: 32
# wandb: 	decay_rate: 0.0088
# wandb: 	epochs: 10
# wandb: 	learning_rate: 0.0007
# wandb: 	optimizer: SGD
# wandb: 	sched: tanh
# wandb: 	warmup_epochs: 6
# wandb: 	warmup_lr: 0.0027
# wandb: Agent Starting Run: 57qd28my with config:
# wandb: 	batch_size: 40
# wandb: 	decay_rate: 0.00030000000000000003
# wandb: 	epochs: 10
# wandb: 	learning_rate: 0.0032
# wandb: 	optimizer: SGD
# wandb: 	sched: poly
# wandb: 	warmup_epochs: 8
# wandb: 	warmup_lr: 0.002
# wandb: Sweep Agent: Waiting for job.
# wandb: Job received.
# wandb: Agent Starting Run: azae10cj with config:
# wandb: 	batch_size: 96
# wandb: 	decay_rate: 0.0031000000000000003
# wandb: 	epochs: 10
# wandb: 	learning_rate: 0.0016
# wandb: 	optimizer: adam
# wandb: 	sched: tanh
# wandb: 	warmup_epochs: 6
# wandb: 	warmup_lr: 0.005
# wandb: Agent Starting Run: uwvdk28g with config:
# wandb: 	batch_size: 88
# wandb: 	decay_rate: 0.0059
# wandb: 	epochs: 10
# wandb: 	learning_rate: 0.0021000000000000003
# wandb: 	optimizer: SGD
# wandb: 	sched: tanh
# wandb: 	warmup_epochs: 6
# wandb: 	warmup_lr: 0.001
# wandb: Sweep Agent: Waiting for job.
# wandb: Job received.
# wandb: Agent Starting Run: fj2x17oz with config:
# wandb: 	batch_size: 112
# wandb: 	decay_rate: 0.009000000000000001
# wandb: 	epochs: 10
# wandb: 	learning_rate: 0.0037
# wandb: 	optimizer: SGD
# wandb: 	sched: poly
# wandb: 	warmup_epochs: 6
# wandb: 	warmup_lr: 0.0016
# wandb: Agent Starting Run: 5n2lqb6d with config:
# wandb: 	batch_size: 48
# wandb: 	decay_rate: 0.005
# wandb: 	epochs: 10
# wandb: 	learning_rate: 0.0038
# wandb: 	optimizer: adam
# wandb: 	sched: cosine
# wandb: 	warmup_epochs: 6
# wandb: 	warmup_lr: 0.0015
# wandb: Sweep Agent: Waiting for job.
# wandb: Job received.
# wandb: Agent Starting Run: livv4yok with config:
# wandb: 	batch_size: 48
# wandb: 	decay_rate: 0.0073
# wandb: 	epochs: 10
# wandb: 	learning_rate: 0.0048
# wandb: 	optimizer: adam
# wandb: 	sched: cosine
# wandb: 	warmup_epochs: 10
# wandb: 	warmup_lr: 0.0011
# wandb: Agent Starting Run: 8q8zjhft with config:
# wandb: 	batch_size: 64
# wandb: 	decay_rate: 0.008700000000000001
# wandb: 	epochs: 10
# wandb: 	learning_rate: 0.0048
# wandb: 	optimizer: adamW
# wandb: 	sched: poly
# wandb: 	warmup_epochs: 4
# wandb: 	warmup_lr: 0.0014
# wandb: Sweep Agent: Waiting for job.
# wandb: Job received.
# wandb: Agent Starting Run: ln1iwikk with config:
# wandb: 	batch_size: 128
# wandb: 	decay_rate: 0.0061
# wandb: 	epochs: 10
# wandb: 	learning_rate: 0.0041
# wandb: 	optimizer: adam
# wandb: 	sched: tanh
# wandb: 	warmup_epochs: 2
# wandb: 	warmup_lr: 0.0021000000000000003
# wandb: Agent Starting Run: 1poyh9ux with config:
# wandb: 	batch_size: 104
# wandb: 	decay_rate: 0.0018000000000000002
# wandb: 	epochs: 10
# wandb: 	learning_rate: 0.0022
# wandb: 	optimizer: adam
# wandb: 	sched: tanh
# wandb: 	warmup_epochs: 6
# wandb: 	warmup_lr: 0.0007
# wandb: Sweep Agent: Waiting for job.
# wandb: Job received.
# wandb: Agent Starting Run: o7pjvxbm with config:
# wandb: 	batch_size: 48
# wandb: 	decay_rate: 0.0036000000000000003
# wandb: 	epochs: 10
# wandb: 	learning_rate: 0.002
# wandb: 	optimizer: adamW
# wandb: 	sched: poly
# wandb: 	warmup_epochs: 4
# wandb: 	warmup_lr: 0.0024
# wandb: Agent Starting Run: 7kl2rp08 with config:
# wandb: 	batch_size: 48
# wandb: 	decay_rate: 0.0004
# wandb: 	epochs: 10
# wandb: 	learning_rate: 0.003
# wandb: 	optimizer: SGD
# wandb: 	sched: cosine
# wandb: 	warmup_epochs: 2
# wandb: 	warmup_lr: 0.0012
# wandb: Sweep Agent: Waiting for job.
# wandb: Job received.
# wandb: Agent Starting Run: zaeldh5d with config:
# wandb: 	batch_size: 56
# wandb: 	decay_rate: 0.0068000000000000005
# wandb: 	epochs: 10
# wandb: 	learning_rate: 0.0033
# wandb: 	optimizer: adamW
# wandb: 	sched: tanh
# wandb: 	warmup_epochs: 2
# wandb: 	warmup_lr: 0.0041
# wandb: Agent Starting Run: ibazp7yo with config:
# wandb: 	batch_size: 64
# wandb: 	decay_rate: 0.0038
# wandb: 	epochs: 10
# wandb: 	learning_rate: 0.0039
# wandb: 	optimizer: SGD
# wandb: 	sched: cosine
# wandb: 	warmup_epochs: 8
# wandb: 	warmup_lr: 0.0025
# wandb: Sweep Agent: Waiting for job.
# wandb: Job received.
# wandb: Agent Starting Run: jtgilxck with config:
# wandb: 	batch_size: 32
# wandb: 	decay_rate: 0.0027
# wandb: 	epochs: 10
# wandb: 	learning_rate: 0.0023
# wandb: 	optimizer: adam
# wandb: 	sched: poly
# wandb: 	warmup_epochs: 2
# wandb: 	warmup_lr: 0.0017
# wandb: Agent Starting Run: 4ywajo1f with config:
# wandb: 	batch_size: 64
# wandb: 	decay_rate: 0.0038
# wandb: 	epochs: 10
# wandb: 	learning_rate: 0.0007
# wandb: 	optimizer: SGD
# wandb: 	sched: poly
# wandb: 	warmup_epochs: 4
# wandb: 	warmup_lr: 0.0028
# wandb: Sweep Agent: Waiting for job.
# wandb: Job received.
# wandb: Agent Starting Run: q8e0qlo7 with config:
# wandb: 	batch_size: 48
# wandb: 	decay_rate: 0.0031000000000000003
# wandb: 	epochs: 10
# wandb: 	learning_rate: 0.0025
# wandb: 	optimizer: adam
# wandb: 	sched: cosine
# wandb: 	warmup_epochs: 4
# wandb: 	warmup_lr: 0.0009000000000000001
# wandb: Agent Starting Run: vkda5cg1 with config:
# wandb: 	batch_size: 72
# wandb: 	decay_rate: 0.0036000000000000003
# wandb: 	epochs: 10
# wandb: 	learning_rate: 0.0045000000000000005
# wandb: 	optimizer: adam
# wandb: 	sched: tanh
# wandb: 	warmup_epochs: 2
# wandb: 	warmup_lr: 0.0033
# wandb: Sweep Agent: Waiting for job.
# wandb: Job received.
# wandb: Agent Starting Run: tcb8nll1 with config:
# wandb: 	batch_size: 88
# wandb: 	decay_rate: 0.0032
# wandb: 	epochs: 10
# wandb: 	learning_rate: 0.0033
# wandb: 	optimizer: SGD
# wandb: 	sched: tanh
# wandb: 	warmup_epochs: 8
# wandb: 	warmup_lr: 0.002
# wandb: Agent Starting Run: qk463nfx with config:
# wandb: 	batch_size: 72
# wandb: 	decay_rate: 0.0034
# wandb: 	epochs: 10
# wandb: 	learning_rate: 0.0039
# wandb: 	optimizer: SGD
# wandb: 	sched: cosine
# wandb: 	warmup_epochs: 6
# ...
# wandb: 	batch_size: 56
# wandb: 	decay_rate: 0.0033
# wandb: 	epochs: 10
# wandb: 	learning_rate: 0.0016
# wandb: 	optimizer: adamW
# wandb: 	sched: poly
# wandb: 	warmup_epochs: 4
# wandb: 	warmup_lr: 0.0045000000000000005
# wandb: Sweep Agent: Waiting for job.
# wandb: Job received.
# wandb: Agent Starting Run: q11o3eur with config:
# wandb: 	batch_size: 40
# wandb: 	decay_rate: 0.0021000000000000003
# wandb: 	epochs: 10
# wandb: 	learning_rate: 0.0006000000000000001
# wandb: 	optimizer: adam
# wandb: 	sched: poly
# wandb: 	warmup_epochs: 4
# wandb: 	warmup_lr: 0.0009000000000000001
# wandb: Agent Starting Run: dk56yzrl with config:
# wandb: 	batch_size: 88
# wandb: 	decay_rate: 0.0049
# wandb: 	epochs: 10
# wandb: 	learning_rate: 0.0039
# wandb: 	optimizer: adam
# wandb: 	sched: tanh
# wandb: 	warmup_epochs: 8
# wandb: 	warmup_lr: 0.0011
# wandb: Sweep Agent: Waiting for job.
# wandb: Job received.
# wandb: Agent Starting Run: h32aeoek with config:
# wandb: 	batch_size: 104
# wandb: 	decay_rate: 0.0076
# wandb: 	epochs: 10
# wandb: 	learning_rate: 0.0036000000000000003
# wandb: 	optimizer: adamW
# wandb: 	sched: tanh
# wandb: 	warmup_epochs: 4
# wandb: 	warmup_lr: 0.0023
# wandb: Agent Starting Run: g7l8su13 with config:
# wandb: 	batch_size: 48
# wandb: 	decay_rate: 0.0049
# wandb: 	epochs: 10
# wandb: 	learning_rate: 0.0047
# wandb: 	optimizer: adamW
# wandb: 	sched: tanh
# wandb: 	warmup_epochs: 8
# wandb: 	warmup_lr: 0.0041
# wandb: Sweep Agent: Waiting for job.
# wandb: Job received.
# wandb: Agent Starting Run: m5shbucd with config:
# wandb: 	batch_size: 40
# wandb: 	decay_rate: 0.008400000000000001
# wandb: 	epochs: 10
# wandb: 	learning_rate: 0.0007
# wandb: 	optimizer: SGD
# wandb: 	sched: cosine
# wandb: 	warmup_epochs: 4
# wandb: 	warmup_lr: 0.0035
# wandb: Agent Starting Run: nnrmgtf2 with config:
# wandb: 	batch_size: 48
# wandb: 	decay_rate: 0.006500000000000001
# wandb: 	epochs: 10
# wandb: 	learning_rate: 0.004
# wandb: 	optimizer: SGD
# wandb: 	sched: poly
# wandb: 	warmup_epochs: 6
# wandb: 	warmup_lr: 0.004200000000000001
# wandb: Sweep Agent: Waiting for job.
# wandb: Job received.
# wandb: Agent Starting Run: 1l8sf3p1 with config:
# wandb: 	batch_size: 104
# wandb: 	decay_rate: 0.0059
# wandb: 	epochs: 10
# wandb: 	learning_rate: 0.0015
# wandb: 	optimizer: adamW
# wandb: 	sched: poly
# wandb: 	warmup_epochs: 2
# wandb: 	warmup_lr: 0.0007
# wandb: Agent Starting Run: mgv8gl51 with config:
# wandb: 	batch_size: 72
# wandb: 	decay_rate: 0.0057
# wandb: 	epochs: 10
# wandb: 	learning_rate: 0.0038
# wandb: 	optimizer: adamW
# wandb: 	sched: poly
# wandb: 	warmup_epochs: 8
# wandb: 	warmup_lr: 0.0017
# wandb: Sweep Agent: Waiting for job.
# wandb: Job received.
# wandb: Agent Starting Run: xhoy6axe with config:
# wandb: 	batch_size: 96
# wandb: 	decay_rate: 0.0073
# wandb: 	epochs: 10
# wandb: 	learning_rate: 0.0043
# wandb: 	optimizer: SGD
# wandb: 	sched: cosine
# wandb: 	warmup_epochs: 6
# wandb: 	warmup_lr: 0.0036000000000000003
# wandb: Agent Starting Run: zkrghr7r with config:
# wandb: 	batch_size: 48
# wandb: 	decay_rate: 0.0045000000000000005
# wandb: 	epochs: 10
# wandb: 	learning_rate: 0.0048
# wandb: 	optimizer: adamW
# wandb: 	sched: cosine
# wandb: 	warmup_epochs: 2
# wandb: 	warmup_lr: 0.0022
# wandb: Sweep Agent: Waiting for job.
# wandb: Job received.
# wandb: Agent Starting Run: 8fl487e3 with config:
# wandb: 	batch_size: 104
# wandb: 	decay_rate: 0.0054
# wandb: 	epochs: 10
# wandb: 	learning_rate: 0.0012
# wandb: 	optimizer: adamW
# wandb: 	sched: cosine
# wandb: 	warmup_epochs: 2
# wandb: 	warmup_lr: 0.0035
# wandb: Agent Starting Run: zyszeh5u with config:
# wandb: 	batch_size: 32
# wandb: 	decay_rate: 0.0053
# wandb: 	epochs: 10
# wandb: 	learning_rate: 0.0011
# wandb: 	optimizer: adam
# wandb: 	sched: tanh
# wandb: 	warmup_epochs: 10
# wandb: 	warmup_lr: 0.001
# wandb: Sweep Agent: Waiting for job.
# wandb: Job received.
# wandb: Agent Starting Run: yhxa9yfk with config:
# wandb: 	batch_size: 40
# wandb: 	decay_rate: 0.0041
# wandb: 	epochs: 10
# wandb: 	learning_rate: 0.0024
# wandb: 	optimizer: adamW
# wandb: 	sched: poly
# wandb: 	warmup_epochs: 10
# wandb: 	warmup_lr: 0.0022
# wandb: Agent Starting Run: zaeldh5d with config:
# wandb: 	batch_size: 56
# wandb: 	decay_rate: 0.0068000000000000005
# wandb: 	epochs: 10
# wandb: 	learning_rate: 0.0033
# wandb: 	optimizer: adamW
# wandb: 	sched: tanh
# wandb: 	warmup_epochs: 2
# wandb: 	warmup_lr: 0.0041
# wandb: Sweep Agent: Waiting for job.
# wandb: Job received.
# wandb: Agent Starting Run: ibazp7yo with config:
# wandb: 	batch_size: 64
# wandb: 	decay_rate: 0.0038
# wandb: 	epochs: 10
# wandb: 	learning_rate: 0.0039
# wandb: 	optimizer: SGD
# wandb: 	sched: cosine
# wandb: 	warmup_epochs: 8
# wandb: 	warmup_lr: 0.0025
# wandb: Agent Starting Run: jtgilxck with config:
# wandb: 	batch_size: 32
# wandb: 	decay_rate: 0.0027
# wandb: 	epochs: 10
# wandb: 	learning_rate: 0.0023
# wandb: 	optimizer: adam
# wandb: 	sched: poly
# wandb: 	warmup_epochs: 2
# wandb: 	warmup_lr: 0.0017
# wandb: Sweep Agent: Waiting for job.
# wandb: Job received.
# wandb: Agent Starting Run: 4ywajo1f with config:
# wandb: 	batch_size: 64
# wandb: 	decay_rate: 0.0038
# wandb: 	epochs: 10
# wandb: 	learning_rate: 0.0007
# wandb: 	optimizer: SGD
# wandb: 	sched: poly
# wandb: 	warmup_epochs: 4
# wandb: 	warmup_lr: 0.0028
# wandb: Agent Starting Run: q8e0qlo7 with config:
# wandb: 	batch_size: 48
# wandb: 	decay_rate: 0.0031000000000000003
# wandb: 	epochs: 10
# wandb: 	learning_rate: 0.0025
# wandb: 	optimizer: adam
# wandb: 	sched: cosine
# wandb: 	warmup_epochs: 4
# wandb: 	warmup_lr: 0.0009000000000000001
# wandb: Sweep Agent: Waiting for job.
# wandb: Job received.
# wandb: Agent Starting Run: vkda5cg1 with config:
# wandb: 	batch_size: 72
# wandb: 	decay_rate: 0.0036000000000000003
# wandb: 	epochs: 10
# wandb: 	learning_rate: 0.0045000000000000005
# wandb: 	optimizer: adam
# wandb: 	sched: tanh
# wandb: 	warmup_epochs: 2
# wandb: 	warmup_lr: 0.0033
# wandb: Agent Starting Run: tcb8nll1 with config:
# wandb: 	batch_size: 88
# wandb: 	decay_rate: 0.0032
# wandb: 	epochs: 10
# wandb: 	learning_rate: 0.0033
# wandb: 	optimizer: SGD
# wandb: 	sched: tanh
# wandb: 	warmup_epochs: 8
# wandb: 	warmup_lr: 0.002
# wandb: Sweep Agent: Waiting for job.
# wandb: Job received.
# wandb: Agent Starting Run: qk463nfx with config:
# wandb: 	batch_size: 72
# wandb: 	decay_rate: 0.0034
# wandb: 	epochs: 10
# wandb: 	learning_rate: 0.0039
# wandb: 	optimizer: SGD
# wandb: 	sched: cosine
# wandb: 	warmup_epochs: 6
# wandb: 	warmup_lr: 0.004200000000000001
# wandb: Agent Starting Run: n6pthqk0 with config:
# wandb: 	batch_size: 104
# wandb: 	decay_rate: 0.0099
# wandb: 	epochs: 10
# wandb: 	learning_rate: 0.0037
# wandb: 	optimizer: SGD
# wandb: 	sched: cosine
# wandb: 	warmup_epochs: 4
# wandb: 	warmup_lr: 0.0036000000000000003
# wandb: Sweep Agent: Waiting for job.
# wandb: Job received.
# wandb: Agent Starting Run: mpy7btpb with config:
# wandb: 	batch_size: 96
# wandb: 	decay_rate: 0.003
# wandb: 	epochs: 10
# wandb: 	learning_rate: 0.0013000000000000002
# wandb: 	optimizer: SGD
# wandb: 	sched: poly
# wandb: 	warmup_epochs: 2
# wandb: 	warmup_lr: 0.0039
# wandb: Agent Starting Run: 84q2xhik with config:
# wandb: 	batch_size: 64
# wandb: 	decay_rate: 0.0048
# wandb: 	epochs: 10
# wandb: 	learning_rate: 0.0013000000000000002
# wandb: 	optimizer: adam
# wandb: 	sched: cosine
# wandb: 	warmup_epochs: 4
# wandb: 	warmup_lr: 0.0044
# wandb: Sweep Agent: Waiting for job.
# wandb: Job received.
# wandb: Agent Starting Run: xv5guwdb with config:
# wandb: 	batch_size: 88
# wandb: 	decay_rate: 0.0043
# wandb: 	epochs: 10
# wandb: 	learning_rate: 0.0044
# wandb: 	optimizer: SGD
# wandb: 	sched: cosine
# wandb: 	warmup_epochs: 2
# wandb: 	warmup_lr: 0.0012
# wandb: Agent Starting Run: t6ipcz4y with config:
# wandb: 	batch_size: 48
# wandb: 	decay_rate: 0.004200000000000001
# wandb: 	epochs: 10
# wandb: 	learning_rate: 0.0036000000000000003
# wandb: 	optimizer: adam
# wandb: 	sched: poly
# wandb: 	warmup_epochs: 4
# wandb: 	warmup_lr: 0.0036000000000000003
# wandb: Sweep Agent: Waiting for job.
# wandb: Job received.
# wandb: Agent Starting Run: bxk7gfps with config:
# wandb: 	batch_size: 48
# wandb: 	decay_rate: 0.009000000000000001
# wandb: 	epochs: 10
# wandb: 	learning_rate: 0.0006000000000000001
# wandb: 	optimizer: SGD
# wandb: 	sched: cosine
# wandb: 	warmup_epochs: 4
# wandb: 	warmup_lr: 0.0024
# wandb: Agent Starting Run: 5yiu6hcj with config:
# wandb: 	batch_size: 56
# wandb: 	decay_rate: 0.0044
# wandb: 	epochs: 10
# wandb: 	learning_rate: 0.0038
# wandb: 	optimizer: adamW
# wandb: 	sched: cosine
# wandb: 	warmup_epochs: 6
# wandb: 	warmup_lr: 0.0014
# wandb: Sweep Agent: Waiting for job.
# wandb: Job received.
# wandb: Agent Starting Run: ze114ji2 with config:
# wandb: 	batch_size: 40
# wandb: 	decay_rate: 0.006900000000000001
# wandb: 	epochs: 10
# wandb: 	learning_rate: 0.0038
# wandb: 	optimizer: adam
# wandb: 	sched: poly
# wandb: 	warmup_epochs: 8
# wandb: 	warmup_lr: 0.0017
# wandb: Agent Starting Run: r820ts5i with config:
# wandb: 	batch_size: 96
# wandb: 	decay_rate: 0.0054
# wandb: 	epochs: 10
# wandb: 	learning_rate: 0.0015
# wandb: 	optimizer: adamW
# wandb: 	sched: tanh
# wandb: 	warmup_epochs: 4
# wandb: 	warmup_lr: 0.0036000000000000003
# wandb: Sweep Agent: Waiting for job.
# wandb: Job received.
# wandb: Agent Starting Run: 400c9vk6 with config:
# wandb: 	batch_size: 56
# wandb: 	decay_rate: 0.0012
# wandb: 	epochs: 10
# wandb: 	learning_rate: 0.0024
# wandb: 	optimizer: adam
# wandb: 	sched: tanh
# wandb: 	warmup_epochs: 6
# wandb: 	warmup_lr: 0.002
# wandb: Agent Starting Run: uljey3th with config:
# wandb: 	batch_size: 104
# wandb: 	decay_rate: 0.0071
# wandb: 	epochs: 10
# wandb: 	learning_rate: 0.0011
# wandb: 	optimizer: adam
# wandb: 	sched: tanh
# wandb: 	warmup_epochs: 4
# wandb: 	warmup_lr: 0.0031000000000000003
# wandb: Sweep Agent: Waiting for job.
# wandb: Job received.
# wandb: Agent Starting Run: 7orzx5uy with config:
# wandb: 	batch_size: 120
# wandb: 	decay_rate: 0.006
# wandb: 	epochs: 10
# wandb: 	learning_rate: 0.0018000000000000002
# wandb: 	optimizer: adam
# wandb: 	sched: cosine
# wandb: 	warmup_epochs: 6
# wandb: 	warmup_lr: 0.0009000000000000001
# wandb: Agent Starting Run: jsib0fs8 with config:
# wandb: 	batch_size: 40
# wandb: 	decay_rate: 0.0002
# wandb: 	epochs: 10
# wandb: 	learning_rate: 0.0024
# wandb: 	optimizer: adamW
# wandb: 	sched: cosine
# wandb: 	warmup_epochs: 6
# wandb: 	warmup_lr: 0.0034
# wandb: Sweep Agent: Waiting for job.
# wandb: Job received.
# wandb: Agent Starting Run: 0yr03sev with config:
# wandb: 	batch_size: 48
# wandb: 	decay_rate: 0.005200000000000001
# wandb: 	epochs: 10
# wandb: 	learning_rate: 0.0024
# wandb: 	optimizer: SGD
# wandb: 	sched: poly
# wandb: 	warmup_epochs: 2
# wandb: 	warmup_lr: 0.0049
# wandb: Agent Starting Run: 28x9cg8j with config:
# wandb: 	batch_size: 96
# wandb: 	decay_rate: 0.0068000000000000005
# wandb: 	epochs: 10
# wandb: 	learning_rate: 0.0022
# wandb: 	optimizer: adam
# wandb: 	sched: cosine
# wandb: 	warmup_epochs: 2
# wandb: 	warmup_lr: 0.0039
# wandb: Sweep Agent: Waiting for job.
# wandb: Job received.
# wandb: Agent Starting Run: vu70as97 with config:
# wandb: 	batch_size: 40
# wandb: 	decay_rate: 0.006200000000000001
# wandb: 	epochs: 10
# wandb: 	learning_rate: 0.0036000000000000003
# wandb: 	optimizer: adamW
# wandb: 	sched: tanh
# wandb: 	warmup_epochs: 6
# wandb: 	warmup_lr: 0.0044
# wandb: Agent Starting Run: dni0ci52 with config:
# wandb: 	batch_size: 48
# wandb: 	decay_rate: 0.007200000000000001
# wandb: 	epochs: 10
# wandb: 	learning_rate: 0.0026000000000000003
# wandb: 	optimizer: SGD
# wandb: 	sched: poly
# wandb: 	warmup_epochs: 8
# wandb: 	warmup_lr: 0.0023
# wandb: Sweep Agent: Waiting for job.
# wandb: Job received.
# wandb: Agent Starting Run: wpbg1cu1 with config:
# wandb: 	batch_size: 72
# wandb: 	decay_rate: 0.0021000000000000003
# wandb: 	epochs: 10
# wandb: 	learning_rate: 0.0028
# wandb: 	optimizer: adam
# wandb: 	sched: poly
# wandb: 	warmup_epochs: 4
# wandb: 	warmup_lr: 0.0041
# wandb: Agent Starting Run: k4c3tn58 with config:
# wandb: 	batch_size: 64
# wandb: 	decay_rate: 0.0045000000000000005
# wandb: 	epochs: 10
# wandb: 	learning_rate: 0.0017
# wandb: 	optimizer: SGD
# wandb: 	sched: poly
# wandb: 	warmup_epochs: 4
# wandb: 	warmup_lr: 0.0011
# wandb: Sweep Agent: Waiting for job.
# wandb: Job received.
# wandb: Agent Starting Run: dh0ggfj3 with config:
# wandb: 	batch_size: 32
# wandb: 	decay_rate: 0.0031000000000000003
# wandb: 	epochs: 10
# wandb: 	learning_rate: 0.0037
# wandb: 	optimizer: adam
# wandb: 	sched: poly
# wandb: 	warmup_epochs: 4
# wandb: 	warmup_lr: 0.0046
# wandb: Agent Starting Run: 95lugtxj with config:
# wandb: 	batch_size: 32
# wandb: 	decay_rate: 0.0022
# wandb: 	epochs: 10
# wandb: 	learning_rate: 0.0005
# wandb: 	optimizer: adamW
# wandb: 	sched: poly
# wandb: 	warmup_epochs: 2
# wandb: 	warmup_lr: 0.0017
# wandb: Sweep Agent: Waiting for job.
# wandb: Job received.
# wandb: Agent Starting Run: rhep5rri with config:
# wandb: 	batch_size: 88
# wandb: 	decay_rate: 0.0088
# wandb: 	epochs: 10
# wandb: 	learning_rate: 0.0009000000000000001
# wandb: 	optimizer: adamW
# wandb: 	sched: tanh
# wandb: 	warmup_epochs: 2
# wandb: 	warmup_lr: 0.0035
# wandb: Agent Starting Run: l2n045hp with config:
# wandb: 	batch_size: 72
# wandb: 	decay_rate: 0.008400000000000001
# wandb: 	epochs: 10
# wandb: 	learning_rate: 0.004200000000000001
# wandb: 	optimizer: SGD
# wandb: 	sched: cosine
# wandb: 	warmup_epochs: 4
# wandb: 	warmup_lr: 0.0025
# wandb: Sweep Agent: Waiting for job.
# wandb: Job received.
# wandb: Agent Starting Run: s7yoc84e with config:
# wandb: 	batch_size: 32
# wandb: 	decay_rate: 0.0081
# wandb: 	epochs: 10
# wandb: 	learning_rate: 0.0015
# wandb: 	optimizer: adam
# wandb: 	sched: tanh
# wandb: 	warmup_epochs: 8
# wandb: 	warmup_lr: 0.0022
# wandb: Agent Starting Run: 4a6lybgo with config:
# wandb: 	batch_size: 72
# wandb: 	decay_rate: 0.006200000000000001
# wandb: 	epochs: 10
# wandb: 	learning_rate: 0.0011
# wandb: 	optimizer: adam
# wandb: 	sched: tanh
# wandb: 	warmup_epochs: 8
# wandb: 	warmup_lr: 0.0026000000000000003
# wandb: Sweep Agent: Waiting for job.
# wandb: Job received.
# wandb: Agent Starting Run: qyztob46 with config:
# wandb: 	batch_size: 64
# wandb: 	decay_rate: 0.004200000000000001
# wandb: 	epochs: 10
# wandb: 	learning_rate: 0.003
# wandb: 	optimizer: SGD
# wandb: 	sched: poly
# wandb: 	warmup_epochs: 10
# wandb: 	warmup_lr: 0.0048
# wandb: Agent Starting Run: mbtsuzsr with config:
# wandb: 	batch_size: 80
# wandb: 	decay_rate: 0.0079
# wandb: 	epochs: 10
# wandb: 	learning_rate: 0.0036000000000000003
# wandb: 	optimizer: adamW
# wandb: 	sched: tanh
# wandb: 	warmup_epochs: 6
# wandb: 	warmup_lr: 0.0036000000000000003
# wandb: Sweep Agent: Waiting for job.
# wandb: Job received.
# wandb: Agent Starting Run: 2wrvgsm3 with config:
# wandb: 	batch_size: 32
# wandb: 	decay_rate: 0.0085
# wandb: 	epochs: 10
# wandb: 	learning_rate: 0.0018000000000000002
# wandb: 	optimizer: adam
# wandb: 	sched: tanh
# wandb: 	warmup_epochs: 6
# wandb: 	warmup_lr: 0.0008
# wandb: Agent Starting Run: ktxq1139 with config:
# wandb: 	batch_size: 88
# wandb: 	decay_rate: 0.0029
# wandb: 	epochs: 10
# wandb: 	learning_rate: 0.0029
# wandb: 	optimizer: adamW
# wandb: 	sched: cosine
# wandb: 	warmup_epochs: 10
# wandb: 	warmup_lr: 0.0034
# wandb: Agent Starting Run: efsmp1gh with config:
# wandb: 	batch_size: 80
# wandb: 	decay_rate: 0.0091
# wandb: 	epochs: 10
# wandb: 	learning_rate: 0.0043
# wandb: 	optimizer: adam
# wandb: 	sched: poly
# wandb: 	warmup_epochs: 10
# wandb: 	warmup_lr: 0.0024
# mobilevit_xxs
# mobilevit_xxs
# model = mobilevit_xxs will be trained for 10 epochs
# Tracking run with wandb version 0.12.16
# Run data is saved locally in <code>/content/wandb/run-20220517_084614-efsmp1gh</code>
# Syncing run <strong><a href="https://wandb.ai/iaqa/small_is_beautiful/runs/efsmp1gh" target="_blank">mobilevit_xxs</a></strong> to <a href="https://wandb.ai/iaqa/small_is_beautiful" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>Sweep page:  <a href="https://wandb.ai/iaqa/small_is_beautiful/sweeps/9imn7g9l" target="_blank">https://wandb.ai/iaqa/small_is_beautiful/sweeps/9imn7g9l</a>
# {'batch_size': 80, 'decay_rate': 0.0091, 'epochs': 10, 'learning_rate': 0.0043, 'optimizer': 'adam', 'sched': 'poly', 'warmup_epochs': 10, 'warmup_lr': 0.0024}
# mobilevit_xxs
# /usr/local/lib/python3.7/dist-packages/albumentations/augmentations/transforms.py:691: FutureWarning: This class has been deprecated. Please use CoarseDropout
#   FutureWarning,
# currently trianing mobilevit_xxs
# mobilevit_xxs will be saved at drive/MyDrive/0.AVA/results/sweep/mobilevit_xxs/mobilevit_xxs
# Epoch 0/9
# ----------
# 223363
# training
#  47%|████▋     | 823/1746 [22:39<25:08,  1.63s/it]
